# %% [markdown]
# # Testing graph and agent architecture

# %%
from langgraph.graph import StateGraph, END
from typing import Annotated, Literal, TypedDict
from pydantic import BaseModel, Field
from langchain_core.messages import BaseMessage, SystemMessage, HumanMessage, ToolMessage, AIMessage
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_linkup import LinkupSearchTool
from langgraph.checkpoint.memory import InMemorySaver


GEMINI_MODEL_NAME = "gemini-2.5-flash-lite-preview-06-17"
#GEMINI_MODEL_NAME = "gemini-2.5-flash"

# %%
model = ChatGoogleGenerativeAI(model=GEMINI_MODEL_NAME, temperature=0.0, thinking_budget=0)

# %% [markdown]
# ## Prompts

# %%
# Project-specific constants
ENGINE_OR_FRAMEWORK = "Love2D framework"
PROG_LANGUAGE = "Lua"

TECH_ARCHITECT_WRITER_SYSTEM_PROMPT = (
    "You are an expert technical architect in game development using the " + ENGINE_OR_FRAMEWORK
    + " with " + PROG_LANGUAGE + " as the programming language. "
    "Given the feature request below, "
    "create a high-level technical architecture following this exact structure:\n"
    "## System Overview\n"
    "Write 2-3 sentences summarizing what this system does and its main purpose.\n"
    "\n"
    "## Core Components\n"
    "For each major component include component name, purpose, key methods, and data structures.\n"
    "\n"
    "## Component Interactions\n"
    "Describe how components communicate with each other. Include component calls, data passed, and event flow as necessary.\n"
    "\n"
    "## File Organization\n"
    "List the specific files to create and what each contains.\n"
    "\n"
    "## Integration Points\n"
    "Specify how this connects to existing game systems (player stats, save system, input handling, etc.).\n"
    "\n"
    "Requirements:\n"
    "- Include all functionality mentioned in the feature request\n"
    "- Each component should have a single, clear responsibility\n"
    "- Use standard " + ENGINE_OR_FRAMEWORK + " patterns, files, and configurations\n"
    "- Specify data structures inline with best practices for the " + PROG_LANGUAGE + " language\n"
    "- Keep components loosely coupled with clear interfaces\n"
    "\n"
    "Do not include implementation details, specific code, or functionality not requested.\n"
    "-----\n"
)

TECH_ARCHITECT_REVIEWER_SYSTEM_PROMPT = (
    "You are an expert technical architect in game development using the " + ENGINE_OR_FRAMEWORK
    + " with " + PROG_LANGUAGE + " as the programming language. "
    "Review the technical architecture against the original feature request. Check each item below:\n"
    "\n"
    "**Completeness Check:**\n"
    " - Are all features from the request addressed in the architecture?\n"
    " - Does each component have a clear purpose and key methods listed?\n"
    " - Are component interactions and integrations clearly described?\n"
    "\n"
    "**Feasibility Check:**\n"
    " - Are the proposed components appropriate for the " + ENGINE_OR_FRAMEWORK + " and the " + PROG_LANGUAGE + " language?\n"
    " - Are the data structures feasible using " + PROG_LANGUAGE + " formats?\n"
    " - Are the component interactions realistic and efficient?\n"
    "\n"
    "**Simplicity Check:**\n"
    " - Is each component focused on a single responsibility?\n"
    " - Are components loosely coupled?\n"
    " - Is the architecture as simple as possible while meeting requirements?\n"
    "\n"
    "Your response must comply with this output structure:\n"
    " - 'review_status' (str): Approved or Needs Revision,\n"
    " - 'completeness_score' (int): [1-5, where 5 = all features covered],\n"
    " - 'feasibility_score' (int): [1-5, where 5 = fully feasible in " + ENGINE_OR_FRAMEWORK + "/" + PROG_LANGUAGE + "],\n"
    " - 'simplicity_score' (int): [1-5, where 5 = appropriately simple],\n"
    " - 'review_notes' (str): If Needs Revision: describe specific issues to fix. If Approved: leave empty string.\n"
    "\n"
    "Example output format:\n"
    "review_status: Approved\n"
    "completeness_score: 5\n"
    "feasibility_score: 4\n"
    "simplicity_score: 5\n"
    "review_notes: \n"
    "\n"
    "Only approve if ALL scores are 4 or greater. Otherwise mark as 'Needs Revision' and provide specific feedback.\n"
    "-----\n"
)

FIP_WRITER_SYSTEM_PROMPT = (
    "You are an expert game developer using the " + ENGINE_OR_FRAMEWORK + " with "
    + PROG_LANGUAGE + " as the programming language. "
    "Given the technical architecture below, "
    "create a feature implementation plan (FIP) following this exact structure:\n"
    "\n"
    "## Implementation Overview\n"
    "Write 2-3 sentences describing what will be implemented and the overall approach.\n"
    "\n"
    "## Implementation Phases\n"
    "Break work into phases. For each phase:\n"
    "\n"
    "**Phase [X]: [Name] (Days X-Y)**\n"
    " - **Priority:** Critical/High/Medium/Low\n"
    " - **Files to create:** [list specific " + PROG_LANGUAGE + " filenames]\n"
    " - **Files to modify:** [list existing files and what changes]\n"
    " - **Key functions to implement:** [function names with brief descriptions]\n"
    " - **Dependencies:** [what must be completed first]\n"
    "\n"
    "## Integration Instructions\n"
    " - **Where to call new code:** [specific files and functions]\n"
    " - **Required imports:** [require statements needed]\n"
    " - **Initialization:** [where to create instances]\n"
    " - **Game loop integration:** [update/draw call locations]\n"
    "\n"
    "## Testing Requirements\n"
    "For each major component:\n"
    " - **Unit tests:** [specific functions to test]\n"
    " - **Integration tests:** [end-to-end workflows to verify]\n"
    " - **Manual testing steps:** [how to verify functionality works]\n"
    "\n"
    "## File Structure\n"
    "```\n"
    "[project_folder]/\n"
    "├── [component1]\n"
    "├── [component2]\n"
    "└── data/\n"
    "    ├── [datafiles]\n"
    "```\n"
    "\n"
    "Requirements:\n"
    " - Include implementation steps for ALL components from the architecture\n"
    " - Specify exact function names and file locations\n"
    " - Provide concrete testing steps that can be executed\n"
    " - Include all integration points with existing systems\n"
    " - Order phases by dependencies (prerequisites first)\n"
    " - Each phase should take 1-3 days maximum\n"
    "\n"
    "Do not include actual code implementation - focus on what to build and how to integrate it.\n"
    "-----\n"
)

FIP_REVIEWER_SYSTEM_PROMPT = (
    "You are an expert game developer using the " + ENGINE_OR_FRAMEWORK + " with "
    + PROG_LANGUAGE + " as the programming language. "
    "Review the feature implementation "
    "plan (FIP) against the technical architecture. Check each item:\n"
    "\n"
    "**Completeness Check:**\n"
    " 1. Does each architecture component have implementation steps in the FIP?\n"
    " 2. Are all files to create/modify specified with names?\n"
    " 3. Are function names and integration points clearly stated?\n"
    " 4. Are testing requirements specified for each component?\n"
    " 5. Is the file structure/organization defined?\n"
    "\n"
    "**Implementation Quality Check:**\n"
    " 1. Are phases ordered by dependencies (no circular dependencies)?\n"
    " 2. Are phase durations realistic (1-3 days each)?\n"
    " 3. Are integration instructions specific (exact files/functions)?\n"
    " 4. Are testing steps actionable and concrete?\n"
    "\n"
    "**Architecture Alignment Check:**\n"
    " 1. Does the FIP address all components from the architecture?\n"
    " 2. Are the proposed functions aligned with architecture methods?\n"
    " 3. Are data structures and interactions preserved?\n"
    " 4. Does the FIP correctly and efficiently make use of the " + ENGINE_OR_FRAMEWORK + " and " + PROG_LANGUAGE + " features?\n"
    "\n"
    "Your response must comply with this output structure:\n"
    " - 'review_status' (int): Approved or Needs Revision,\n"
    " - 'completeness_score' (int): [1-5, where 5 = all architecture components covered],\n"
    " - 'implementation_score' (int): [1-5, where 5 = clear, actionable instructions],\n"
    " - 'alignment_score' (int): [1-5, where 5 = fully matches architecture],\n"
    " - 'review_notes' (str): If Needs Revision: describe specific issues to fix. If Approved: leave empty string.\n"
    "\n"
    "Example output format:\n"
    "review_status: Approved\n"
    "completeness_score: 5\n"
    "implementation_score: 4\n"
    "alignment_score: 5\n"
    "review_notes: \n"
    "\n"
    "Only approve if ALL scores are 4 or greater. Otherwise mark as 'Needs Revision' and provide specific feedback.\n"
    "-----\n"
)

# %% [markdown]
# ## State Classes

# %%
class ArchitectureReviewOutput(BaseModel):
    review_status: Literal["Approved", "Needs Revision"] = Field(description="Status of the review, either 'Approved' or 'Needs Revision'.", default="Needs Revision")
    review_notes: str = Field(description="Detailed feedback on the document being reviewed. If the document is approved, this should be an empty string.", default="")
    completeness_score: int = Field(ge=1, le=5, description="Score for completeness", default=1)
    feasibility_score: int = Field(ge=1, le=5, description="Score for feasibility", default=1)
    simplicity_score: int = Field(ge=1, le=5, description="Score for simplicity", default=1)

class FIPReviewOutput(BaseModel):
    review_status: Literal["Approved", "Needs Revision"] = Field(description="Status of the review, either 'Approved' or 'Needs Revision'.", default="Needs Revision")
    review_notes: str = Field(description="Detailed feedback on the document being reviewed. If the document is approved, this should be an empty string.", default="")
    completeness_score: int = Field(ge=1, le=5, description="Score for completeness", default=1)
    implementation_score: int = Field(ge=1, le=5, description="Score for implementation quality", default=1)
    alignment_score: int = Field(ge=1, le=5, description="Score for architecture alignment", default=1)

class Review(BaseModel):
    """Review ouptut format for the review agents."""
    document_type: Literal["architecture_plan", "feature_implementation_plan"]
    review_output: ArchitectureReviewOutput | FIPReviewOutput
    review_count: int = 0
    max_reviews_allowed: int = 3

class WorkflowState(BaseModel):
    """
    Represents the state of the total workflow. This is the highest level state.
    """
    feature_request: str= ""
    architecture_plan: str = ""
    feature_implementation_plan: str = ""
    ap_review: Review = Field(default_factory=lambda: Review(
        document_type="architecture_plan",
        review_output=ArchitectureReviewOutput(
            review_status="Needs Revision",
            review_notes="",
            completeness_score=1,
            feasibility_score=1,
            simplicity_score=1
        )
    ))
    fip_review: Review = Field(default_factory=lambda: Review(
        document_type="feature_implementation_plan",
        review_output=FIPReviewOutput(
            review_status="Needs Revision",
            review_notes="",
            completeness_score=1,
            implementation_score=1,
            alignment_score=1
        )
    ))

# %% [markdown]
# ## Nodes

# %%
def parse_review_response(content: str, review_type: str) -> ArchitectureReviewOutput | FIPReviewOutput:
    lines = content.strip().split('\n')
    data = {}
    
    for line in lines:
        if ':' in line:
            key, value = line.split(':', 1)
            key = key.strip().lower().replace(' ', '_').replace('"', "").replace("'", "")
            value = value.strip().replace('"', "").replace("'", "").replace(",", "")
            
            if key == 'review_status':
                data[key] = value
            elif key.endswith('_score'):
                data[key] = int(value) if value.isdigit() else 1
            elif key == 'review_notes':
                data[key] = value
            else:
                print(f"Unknown key: {key}, value: {value}")

    if review_type == "architecture":
        return ArchitectureReviewOutput(**data)
    else:
        return FIPReviewOutput(**data)

def tech_arch_writer_node(state: WorkflowState) -> dict:
    """
    Node to write the technical architecture.
    """
    # Create the system message with the prompt
    system_msg = SystemMessage(content=TECH_ARCHITECT_WRITER_SYSTEM_PROMPT)
    feature_content = f"Feature request:\n{state.feature_request}"
    
    # If you need tools, bind them to the model
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools = model #.bind_tools(tools)
    
    # Create messages list
    if state.ap_review.review_count > 0:
        previous_draft = f"\nThis is the previous draft of the architecture plan:\n{state.architecture_plan}\n\n"
        review_feedback = f"Review feedback to address:\n{state.ap_review.review_output.review_notes}\n\n"
        feature_msg = HumanMessage(content=feature_content + previous_draft + review_feedback)
    else:
        feature_msg = HumanMessage(content=feature_content)
    
    messages = [system_msg, feature_msg]
    
    # Invoke the model
    response = model_with_tools.invoke(messages)

    if hasattr(response, 'usage_metadata') and response.usage_metadata:
        print(f"Tech Arch Writer - Input tokens: {response.usage_metadata.get('input_tokens', 'N/A')}")
        print(f"Tech Arch Writer - Output tokens: {response.usage_metadata.get('output_tokens', 'N/A')}")
        print(f"Tech Arch Writer - Total tokens: {response.usage_metadata.get('total_tokens', 'N/A')}")
    
    # Return the update to state
    return {"architecture_plan": response.content}

def tech_arch_validator_node(state: WorkflowState) -> dict:
    """
    Node to validate the technical architecture.
    """
    print(f"Starting architecture validation...")
    # Create the system message
    system_msg = SystemMessage(content=TECH_ARCHITECT_REVIEWER_SYSTEM_PROMPT)
    feature_req = f"Original feature request:\n{state.feature_request}\n-----\n"
    ap_draft = f"Technical architecture to review:\n{state.architecture_plan}\n-----\n"
    task_msg = HumanMessage(content=feature_req + ap_draft)
    
    # Use structured output to ensure proper formatting
    model_with_structured_output = model #.with_structured_output(ArchitectureReviewOutput)
    
    # Add tools if needed (bind tools before structured output)
    #tools = [LinkupSearchTool()]
    model_with_tools_and_structure = model_with_structured_output#.bind_tools(tools)
    
    # Invoke model
    response = model_with_tools_and_structure.invoke([system_msg, task_msg])
    parsed_response = parse_review_response(response.content, "architecture")

    if hasattr(response, 'usage_metadata') and response.usage_metadata:
        print(f"Tech Arch Reviewer - Input tokens: {response.usage_metadata.get('input_tokens', 'N/A')}")
        print(f"Tech Arch Reviewer - Output tokens: {response.usage_metadata.get('output_tokens', 'N/A')}")
        print(f"Tech Arch Reviewer - Total tokens: {response.usage_metadata.get('total_tokens', 'N/A')}")
    # response is now a ReviewOutput object, no parsing needed!
    updated_review = Review(
        document_type="architecture_plan",
        review_output=parsed_response,
        review_count=state.ap_review.review_count + 1,
        max_reviews_allowed=state.ap_review.max_reviews_allowed
    )
    if parsed_response.review_status == "Needs Revision":
        print(f"Architecture review notes: {parsed_response.review_notes}")
    
    return {"ap_review": updated_review}

def feature_impl_writer(state: WorkflowState) -> dict:
    """
    Node to write the feature implementation plan. Includes the subgraph to both write the plan and
    call tools.
    """
    system_msg = SystemMessage(content=FIP_WRITER_SYSTEM_PROMPT)
    task_content = f"Technical architecture:\n{state.architecture_plan}"
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools = model#.bind_tools(tools)

    if state.fip_review.review_count > 0:
        previous_draft = f"Previously submitted draft of the feature implementation plan:\n{state.feature_implementation_plan}\n\n"
        review_feedback = f"Please address this feedback in your next draft of the feature implementation plan:\n{state.fip_review.review_output.review_notes}\n\n"
        task_msg = HumanMessage(content=task_content + previous_draft + review_feedback)
    else:
        task_msg = HumanMessage(content=task_content)
    
    messages = [system_msg, task_msg]
    # Invoke the model
    response = model_with_tools.invoke(messages)
    return {"feature_implementation_plan": response.content}

def feature_impl_validator_node(state: WorkflowState) -> dict:
    """
    Node to validate the feature implementation plan. Includes the subgraph to both review the plan and
    call tools.
    """
    system_msg = SystemMessage(content=FIP_REVIEWER_SYSTEM_PROMPT)
    ap_draft = f"Technical architecture:\n{state.architecture_plan}\n-----\n"
    fip_draft = f"Feature implementation plan to review:\n{state.feature_implementation_plan}\n-----\n"
    task_msg = HumanMessage(content=ap_draft + fip_draft)
    model_with_structured_output = model #.with_structured_output(FIPReviewOutput)
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools_and_structure = model_with_structured_output#.bind_tools(tools)
    response = model_with_tools_and_structure.invoke([system_msg, task_msg])
    parsed_response = parse_review_response(response.content, "fip")
    updated_review = Review(
        document_type="feature_implementation_plan",
        review_output=parsed_response,
        review_count=state.fip_review.review_count + 1,
        max_reviews_allowed=state.fip_review.max_reviews_allowed
    )
    if parsed_response.review_status == "Needs Revision":
        print(f"Feature implementation plan review notes: {parsed_response.review_notes}")
    return {"fip_review": updated_review}

def tech_arch_approval(state: WorkflowState) -> str:
    """
    Node to approve the technical architecture.
    """
    if state.ap_review.review_count >= state.ap_review.max_reviews_allowed:
        return "Review limit reached"
    if (
        (state.ap_review.review_output.completeness_score >= 4) &
        (state.ap_review.review_output.feasibility_score >= 4) &
        (state.ap_review.review_output.simplicity_score >= 4)
     ):
        return "Approved"
    else:
        return "Needs Revision"

def feature_impl_approval(state: WorkflowState) -> str:
    """
    Node to approve the feature implementation plan.
    """
    if state.fip_review.review_count >= state.fip_review.max_reviews_allowed:
        return "Review limit reached"
    if (
        (state.fip_review.review_output.completeness_score >= 4) &
        (state.fip_review.review_output.implementation_score >= 4) &
        (state.fip_review.review_output.alignment_score >= 4)
     ):
        return "Approved"
    else:
        return "Needs Revision"

# %% [markdown]
# ## Graphs

# %%
# Create the workflow graph
workflow_builder = StateGraph(WorkflowState)

# Add nodes
workflow_builder.add_node("tech_arch_writer", tech_arch_writer_node)
workflow_builder.add_node("tech_arch_validator", tech_arch_validator_node)
workflow_builder.add_node("feature_impl_writer", feature_impl_writer)
workflow_builder.add_node("feature_impl_validator", feature_impl_validator_node)

# Add edges
workflow_builder.add_edge("tech_arch_writer", "tech_arch_validator")
workflow_builder.add_edge("feature_impl_writer", "feature_impl_validator")

# Add control flow
workflow_builder.set_entry_point("tech_arch_writer")
workflow_builder.add_conditional_edges(
    "tech_arch_validator",
    tech_arch_approval,
    {
        "Approved": "feature_impl_writer",
        "Needs Revision": "tech_arch_writer",
        "Review limit reached": END
    }
)
workflow_builder.add_conditional_edges(
    "feature_impl_validator",
    feature_impl_approval,
    {
        "Approved": END,
        "Needs Revision": END, #"feature_impl_writer",
        "Review limit reached": END
    }
)

# Compile the graph
workflow_graph = workflow_builder.compile(
    name="Feature Development Workflow"
)

# %%
CASE = 3

if CASE == 1:
    response = workflow_graph.invoke({"feature_request": "Implement a dash feature for the first person movement controller."})
elif CASE == 2:
    response = workflow_graph.invoke({"feature_request": """Overview
Implement a comprehensive player inventory system that allows players to collect, manage, and use items throughout the game. This system should support both consumable and equipment items with a user-friendly interface.
Functional Requirements
Core Inventory Management

Grid-based storage: 20-slot inventory grid (4x5 layout) where each item occupies one slot
Item stacking: Consumable items stack up to 99 per slot, equipment items don't stack
Item sorting: Automatic sorting option that groups items by type (consumables, weapons, armor, misc)
Item filtering: Search functionality to quickly locate specific items by name or type

Item Types and Properties

Consumable Items: Health potions, mana potions, food items with immediate use effects
Equipment Items: Weapons, armor pieces, accessories that modify player stats when equipped
Quest Items: Special items that cannot be dropped or sold, marked with unique visual indicator
Crafting Materials: Basic materials used in future crafting system (prepare data structure)

User Interface

Inventory Window: Accessible via 'I' key, displays item grid with item icons and quantity
Item Tooltips: Hover over items to show name, description, stats, and value
Context Menu: Right-click items for options (use, drop, examine)
Drag & Drop: Click and drag items to rearrange inventory slots
Equipment Slots: Separate UI panel showing currently equipped weapon and armor

Item Acquisition & Removal

Item Pickup: Players walk over dropped items to automatically collect them
Item Dropping: Drop items from inventory to the game world at player location
Item Usage: Consumables apply effects immediately and are removed from inventory
Equipment: Click equipment items to equip/unequip, replacing current equipment

Technical Requirements
Data Persistence

Save/load inventory state between game sessions
Maintain item properties and quantities accurately
Handle equipped items persistence

Performance Constraints

Inventory operations should not cause frame drops
Support up to 1000 different item types in game data
Efficient item lookup and manipulation algorithms

Integration Points

Player Stats System: Equipment items modify player health, damage, speed stats
Game World: Items can be dropped and picked up from the environment
Future Systems: Data structure should accommodate future crafting and trading systems

User Experience Goals

Intuitive drag-and-drop interface similar to popular RPG games
Clear visual feedback for all inventory operations
Responsive controls with no input lag
Consistent visual design matching game's art style

Success Criteria

Players can successfully manage 20+ items without confusion
All inventory operations complete within 50ms
No item duplication or loss bugs
Save/load maintains exact inventory state
UI remains usable at all supported screen resolutions (800x600 to 1920x1080)"""})
if CASE == 3:
    response = workflow_graph.invoke({"feature_request": """Overview
Implement a comprehensive NPC dialogue system that allows players to engage in conversations with non-player characters. The system should support branching conversations, conditional dialogue based on game state, and integration with quest and character progression systems.
Functional Requirements
Core Dialogue Management

Conversation Trees: Support branching dialogue with multiple player response options
Conditional Dialogue: Show/hide dialogue options based on player stats, inventory items, quest progress, or previous choices
Character Memory: NPCs remember previous conversations and player actions
Multiple Conversation Types: Support for shop dialogues, quest givers, lore/information NPCs, and story characters

Dialogue Content Structure

Speaker Identification: Clear indication of who is speaking (NPC name, portrait)
Text Formatting: Support for text styling (bold, italic, color changes for emphasis)
Choice Consequences: Player dialogue choices affect NPC relationship, quest outcomes, or story progression
Repeatable Dialogues: Some conversations can be repeated, others are one-time only

User Interface

Dialogue Window: Modal dialogue box that appears when talking to NPCs
Text Display: Smooth text reveal animation with configurable speed and instant-show option
Choice Selection: Numbered dialogue choices selectable via keyboard (1-9) or mouse click
Speaker Portraits: Display character portraits alongside dialogue text
Close/Exit Options: ESC key or "Goodbye" option to end conversations

NPC Interaction

Trigger System: Conversations start when player presses interaction key near NPCs
Visual Indicators: Show interaction prompts when player is near talkable NPCs
Conversation Range: NPCs only respond when player is within interaction distance
Multiple NPCs: Handle multiple NPCs in close proximity without confusion

Technical Requirements
Data Management

External Content Files: Dialogue content stored in JSON/XML files for easy editing by non-programmers
Localization Support: Structure data to accommodate multiple languages in the future
Dynamic Content Loading: Load dialogue content on-demand to minimize memory usage
Content Validation: Verify dialogue trees have no broken references or unreachable nodes

Performance Constraints

Smooth Text Animation: Text reveal should maintain 60 FPS
Quick Response Time: Dialogue window opening/closing should be under 100ms
Memory Efficiency: Only keep active conversation data in memory
Large Dialogue Support: Handle conversations with 100+ dialogue nodes without performance issues

Integration Points

Quest System: Trigger quest start/completion through dialogue choices
Inventory System: Check for specific items during conversations, give/take items
Player Stats: Reference player level, skills, or attributes in dialogue conditions
Game State: Access global game flags and story progression variables
Audio System: Play voice acting clips or sound effects during conversations
Save System: Persist NPC conversation history and relationship states

User Experience Goals

Natural Flow: Conversations feel organic and responsive to player choices
Clear Navigation: Players always understand their available options
Skip Options: Allow players to speed through or skip previously seen dialogue
Accessibility: Support for different reading speeds and visual accessibility needs
Immersive Presentation: Dialogue feels integrated into the game world, not intrusive

Success Criteria

Conversation Completion: Players can successfully complete multi-branch conversations without confusion
Performance: All dialogue operations complete without frame drops
Content Flexibility: Non-technical team members can create and modify dialogue content
State Persistence: NPC conversation states save/load correctly across game sessions
Choice Impact: Player dialogue choices have visible consequences in subsequent conversations
Bug-Free Navigation: No dialogue tree dead-ends or unreachable content
Scalability: System supports 50+ unique NPCs with complex conversation trees
"""})
# Out:
# Tech Arch Writer - Input tokens: 939
# Tech Arch Writer - Output tokens: 2731
# Tech Arch Writer - Total tokens: 3670
# Starting architecture validation...
# Tech Arch Reviewer - Input tokens: 3813
# Tech Arch Reviewer - Output tokens: 34
# Tech Arch Reviewer - Total tokens: 3847

# %%
for k,v in response.items():
    print(f"\n---\n{k}")
    print(v)
# Out:
# ---
# feature_request
# Overview
# Implement a comprehensive NPC dialogue system that allows players to engage in conversations with non-player characters. The system should support branching conversations, conditional dialogue based on game state, and integration with quest and character progression systems.
# Functional Requirements
# Core Dialogue Management
#
# Conversation Trees: Support branching dialogue with multiple player response options
# Conditional Dialogue: Show/hide dialogue options based on player stats, inventory items, quest progress, or previous choices
# Character Memory: NPCs remember previous conversations and player actions
# Multiple Conversation Types: Support for shop dialogues, quest givers, lore/information NPCs, and story characters
#
# Dialogue Content Structure
#
# Speaker Identification: Clear indication of who is speaking (NPC name, portrait)
# Text Formatting: Support for text styling (bold, italic, color changes for emphasis)
# Choice Consequences: Player dialogue choices affect NPC relationship, quest outcomes, or story progression
# Repeatable Dialogues: Some conversations can be repeated, others are one-time only
#
# User Interface
#
# Dialogue Window: Modal dialogue box that appears when talking to NPCs
# Text Display: Smooth text reveal animation with configurable speed and instant-show option
# Choice Selection: Numbered dialogue choices selectable via keyboard (1-9) or mouse click
# Speaker Portraits: Display character portraits alongside dialogue text
# Close/Exit Options: ESC key or "Goodbye" option to end conversations
#
# NPC Interaction
#
# Trigger System: Conversations start when player presses interaction key near NPCs
# Visual Indicators: Show interaction prompts when player is near talkable NPCs
# Conversation Range: NPCs only respond when player is within interaction distance
# Multiple NPCs: Handle multiple NPCs in close proximity without confusion
#
# Technical Requirements
# Data Management
#
# External Content Files: Dialogue content stored in JSON/XML files for easy editing by non-programmers
# Localization Support: Structure data to accommodate multiple languages in the future
# Dynamic Content Loading: Load dialogue content on-demand to minimize memory usage
# Content Validation: Verify dialogue trees have no broken references or unreachable nodes
#
# Performance Constraints
#
# Smooth Text Animation: Text reveal should maintain 60 FPS
# Quick Response Time: Dialogue window opening/closing should be under 100ms
# Memory Efficiency: Only keep active conversation data in memory
# Large Dialogue Support: Handle conversations with 100+ dialogue nodes without performance issues
#
# Integration Points
#
# Quest System: Trigger quest start/completion through dialogue choices
# Inventory System: Check for specific items during conversations, give/take items
# Player Stats: Reference player level, skills, or attributes in dialogue conditions
# Game State: Access global game flags and story progression variables
# Audio System: Play voice acting clips or sound effects during conversations
# Save System: Persist NPC conversation history and relationship states
#
# User Experience Goals
#
# Natural Flow: Conversations feel organic and responsive to player choices
# Clear Navigation: Players always understand their available options
# Skip Options: Allow players to speed through or skip previously seen dialogue
# Accessibility: Support for different reading speeds and visual accessibility needs
# Immersive Presentation: Dialogue feels integrated into the game world, not intrusive
#
# Success Criteria
#
# Conversation Completion: Players can successfully complete multi-branch conversations without confusion
# Performance: All dialogue operations complete without frame drops
# Content Flexibility: Non-technical team members can create and modify dialogue content
# State Persistence: NPC conversation states save/load correctly across game sessions
# Choice Impact: Player dialogue choices have visible consequences in subsequent conversations
# Bug-Free Navigation: No dialogue tree dead-ends or unreachable content
# Scalability: System supports 50+ unique NPCs with complex conversation trees
#
#
# ---
# architecture_plan
# ## System Overview
# This system provides a comprehensive framework for managing Non-Player Character (NPC) dialogue within the game. It enables players to engage in branching conversations, with dialogue options dynamically influenced by game state, player attributes, and past interactions, fostering a more immersive and responsive narrative experience.
#
# ## Core Components
#
# *   **DialogueManager**
#     *   **Purpose:** Orchestrates the entire dialogue system, managing the loading, parsing, and execution of conversation trees. It acts as the central hub for all dialogue-related operations.
#     *   **Key Methods:**
#         *   `startConversation(npcId, player)`: Initiates a conversation with a specific NPC.
#         *   `getCurrentDialogueNode()`: Returns the currently displayed dialogue node.
#         *   `selectPlayerChoice(choiceIndex)`: Processes the player's selected dialogue choice.
#         *   `advanceDialogue()`: Moves to the next dialogue node based on player input or automatic progression.
#         *   `endConversation()`: Closes the dialogue interface and cleans up active conversation data.
#         *   `loadConversationData(npcId)`: Loads dialogue content for a given NPC.
#         *   `validateConversationTree(conversationData)`: Checks for structural integrity and valid references.
#     *   **Data Structures:**
#         *   `activeConversation`: A table holding the current conversation's state, including `npcId`, `currentNodeId`, `conversationHistory` (e.g., a list of visited node IDs), and `npcMemory` (e.g., a table of flags or relationship values).
#         *   `conversationDataCache`: A table storing loaded conversation trees, keyed by `npcId`.
#
# *   **DialogueParser**
#     *   **Purpose:** Responsible for loading and parsing dialogue content from external files (JSON/XML), validating its structure, and converting it into an internal, usable format.
#     *   **Key Methods:**
#         *   `parseFile(filePath)`: Reads and parses dialogue data from a specified file.
#         *   `validateStructure(data)`: Performs checks for required fields, valid node IDs, and branching logic.
#         *   `buildConversationTree(parsedData)`: Organizes parsed data into a traversable tree structure.
#     *   **Data Structures:**
#         *   `ConversationNode`: A table representing a single dialogue segment, containing:
#             *   `id`: Unique identifier for the node.
#             *   `speaker`: The NPC speaking (e.g., `npcId` or a specific character name).
#             *   `portrait`: Path to the speaker's portrait image.
#             *   `text`: The dialogue text.
#             *   `formatting`: Table of text formatting instructions (e.g., `{ bold = true, color = {1, 0, 0} }`).
#             *   `choices`: A table of player response options, each with:
#                 *   `text`: The player's choice text.
#                 *   `next_node_id`: The ID of the node to transition to.
#                 *   `conditions`: A table of conditions that must be met for this choice to be visible/selectable.
#                 *   `consequences`: A table of actions to perform upon selection (e.g., quest updates, item changes).
#             *   `is_repeatable`: Boolean indicating if this node can be revisited.
#             *   `next_node_id_default`: The ID of the node to transition to if no player choice is made or if it's an NPC-only line.
#
# *   **DialogueUI**
#     *   **Purpose:** Manages the visual presentation of the dialogue interface, including the dialogue window, text display, speaker portraits, and player choice selection.
#     *   **Key Methods:**
#         *   `showDialogueWindow(nodeData)`: Displays the dialogue window with the provided node data.
#         *   `updateTextDisplay(text, animationSpeed)`: Renders the dialogue text with animation.
#         *   `displayChoices(choices)`: Shows the available player choices.
#         *   `hideDialogueWindow()`: Closes the dialogue window.
#         *   `handleInput(input)`: Processes player input for choice selection or closing the dialogue.
#     *   **Data Structures:**
#         *   `dialogueWindow`: A table representing the UI element, containing properties like position, size, and visibility.
#         *   `textDisplay`: A table managing the text rendering, including current text, animation state, and speed.
#         *   `choiceButtons`: A table of UI elements representing player choices.
#         *   `speakerPortrait`: A table managing the display of the NPC's portrait.
#
# *   **ConditionEvaluator**
#     *   **Purpose:** Evaluates dialogue conditions based on the current game state, player stats, inventory, and NPC memory.
#     *   **Key Methods:**
#         *   `evaluate(conditions, player, gameState, npcMemory)`: Checks if a set of conditions is met.
#     *   **Data Structures:**
#         *   `Condition`: A table defining a specific check, e.g., `{ type = "hasItem", item = "key_of_destiny" }`, `{ type = "playerStat", stat = "strength", operator = ">=", value = 10 }`, `{ type = "questProgress", questId = "main_quest_1", status = "started" }`, `{ type = "npcMemory", key = "met_before", value = true }`.
#
# *   **ConsequenceHandler**
#     *   **Purpose:** Executes actions triggered by player dialogue choices, such as updating quests, modifying inventory, or altering NPC relationships.
#     *   **Key Methods:**
#         *   `execute(consequences, player, gameState, npcMemory)`: Processes a list of consequences.
#     *   **Data Structures:**
#         *   `Consequence`: A table defining an action, e.g., `{ type = "startQuest", questId = "side_quest_2" }`, `{ type = "addItem", itemId = "potion", quantity = 3 }`, `{ type = "modifyRelationship", npcId = "merchant_bob", amount = 5 }`, `{ type = "setGameStateFlag", flag = "dialogue_choice_1_made", value = true }`.
#
# *   **NPCInteractionTrigger**
#     *   **Purpose:** Detects when the player is within range of an NPC and prompts for interaction, initiating the dialogue sequence.
#     *   **Key Methods:**
#         *   `update(player, npcs)`: Checks player proximity to NPCs.
#         *   `isPlayerNearNPC(player, npc)`: Determines if the player is within the interaction range of an NPC.
#         *   `showInteractionPrompt(npc)`: Displays a visual indicator above an interactable NPC.
#         *   `hideInteractionPrompt(npc)`: Hides the prompt when the player moves away.
#     *   **Data Structures:**
#         *   `interactionRange`: A configurable float defining the distance for interaction.
#         *   `promptIndicator`: A visual element (e.g., a sprite) to display.
#
# ## Component Interactions
#
# 1.  **Player Interaction:** The `NPCInteractionTrigger` continuously monitors the player's position relative to NPCs. When the player enters the `interactionRange` of an NPC, it displays an interaction prompt.
# 2.  **Initiating Conversation:** When the player presses the interaction key while near an NPC, the `NPCInteractionTrigger` signals the `DialogueManager` to start a conversation with that specific NPC.
# 3.  **Loading Dialogue:** The `DialogueManager` requests the dialogue data for the NPC from the `DialogueParser`. If the data is not cached, the `DialogueParser` loads and parses the relevant external content file. The `DialogueParser` validates the structure and returns a `ConversationTree` to the `DialogueManager`.
# 4.  **Displaying Dialogue:** The `DialogueManager` sets the initial `currentNodeId` and calls `DialogueUI.showDialogueWindow()` with the data for the current node.
# 5.  **Text Animation:** The `DialogueUI` handles the text reveal animation, using a configurable speed. It also displays the speaker's portrait and name.
# 6.  **Player Choice Selection:** If the current node has player choices, `DialogueUI` displays them. When the player selects a choice (via keyboard or mouse), `DialogueUI` passes the choice index to the `DialogueManager`.
# 7.  **Processing Choices:** The `DialogueManager` retrieves the selected choice's data. It then uses the `ConditionEvaluator` to check if the choice is currently available based on game state. If available, it executes any associated `ConsequenceHandler` actions and determines the `next_node_id`.
# 8.  **Advancing Conversation:** The `DialogueManager` updates its `currentNodeId` and calls `DialogueUI.showDialogueWindow()` with the data for the new node. This process repeats until a terminal node is reached or the player chooses to exit.
# 9.  **Exiting Conversation:** The player can exit by selecting a "Goodbye" option or pressing ESC. The `DialogueUI` captures this input and informs the `DialogueManager`, which then calls `DialogueUI.hideDialogueWindow()` and cleans up `activeConversation` data.
# 10. **NPC Memory & State:** The `ConditionEvaluator` and `ConsequenceHandler` interact with external systems (Quest System, Inventory System, Player Stats, Game State) and the `activeConversation.npcMemory` to check conditions and apply consequences.
#
# ## File Organization
#
# *   `src/dialogue/`
#     *   `DialogueManager.lua`: Core logic for managing conversations.
#     *   `DialogueParser.lua`: Handles loading and parsing of dialogue data.
#     *   `DialogueUI.lua`: Manages the user interface elements for dialogue.
#     *   `ConditionEvaluator.lua`: Logic for evaluating dialogue conditions.
#     *   `ConsequenceHandler.lua`: Logic for executing dialogue consequences.
#     *   `NPCInteractionTrigger.lua`: Handles player proximity and interaction prompts.
#     *   `DialogueData.lua`: Defines internal data structures for conversation nodes and trees.
# *   `assets/dialogue/`
#     *   `npc_data/`
#         *   `merchant_bob.json`: Example dialogue data file for a specific NPC.
#         *   `quest_giver_alice.json`: Example dialogue data file.
#     *   `portraits/`
#         *   `bob_portrait.png`: Example NPC portrait.
#         *   `alice_portrait.png`: Example NPC portrait.
# *   `conf.lua`: (Existing Love2D configuration file, may need adjustments for font loading, etc.)
#
# ## Integration Points
#
# *   **Quest System:**
#     *   `ConsequenceHandler` can trigger quest starts, updates, or completions.
#     *   `ConditionEvaluator` can check quest progress or status.
# *   **Inventory System:**
#     *   `ConsequenceHandler` can add or remove items from the player's inventory.
#     *   `ConditionEvaluator` can check for the presence of specific items.
# *   **Player Stats:**
#     *   `ConditionEvaluator` can check player attributes (e.g., strength, charisma) or skills.
#     *   `ConsequenceHandler` could potentially modify player stats (though less common in dialogue).
# *   **Game State:**
#     *   `ConditionEvaluator` can access global game flags, story progression variables, or world states.
#     *   `ConsequenceHandler` can set or modify these global flags.
# *   **Audio System:**
#     *   `DialogueUI` can trigger audio playback for voice lines or sound effects associated with dialogue nodes.
# *   **Save System:**
#     *   The `DialogueManager` will need to save and load the `activeConversation.npcMemory` and potentially `conversationHistory` for each NPC to persist relationship states and past interactions.
# *   **Input Handling:**
#     *   The `DialogueUI` will receive input events from the main input handling system to process player choices and dialogue progression.
# *   **NPC Management System:**
#     *   The `NPCInteractionTrigger` will interact with a system that manages NPC entities to check their positions and identify talkable NPCs.
# *   **Rendering System:**
#     *   The `DialogueUI` will utilize the Love2D rendering API to draw the dialogue window, text, and portraits.
# *   **Font/Text Rendering:**
#     *   The `DialogueUI` will rely on Love2D's font capabilities for displaying dialogue text with formatting.
#
# ---
# feature_implementation_plan
# ## Implementation Overview
#
# This feature plan outlines the implementation of a comprehensive NPC dialogue system. The approach involves creating modular components for dialogue management, parsing, UI display, condition evaluation, consequence handling, and player interaction triggers. These components will be integrated to enable branching conversations influenced by game state and player actions, enhancing narrative immersion.
#
# ## Implementation Phases
#
# **Phase 1: Core Data Structures and Parser (Days 1-3)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/dialogue/DialogueData.lua`
#     - `src/dialogue/DialogueParser.lua`
#  - **Files to modify:**
#     - None
#  - **Key functions to implement:**
#     - `DialogueData.lua`: Define `ConversationNode` and `ConversationTree` table structures.
#     - `DialogueParser.parseFile(filePath)`: Load JSON/XML dialogue files.
#     - `DialogueParser.validateStructure(data)`: Basic validation of loaded data (e.g., presence of `id`, `text`).
#     - `DialogueParser.buildConversationTree(parsedData)`: Convert parsed data into the `ConversationTree` structure.
#  - **Dependencies:** None
#
# **Phase 2: Condition Evaluator and Consequence Handler (Days 4-6)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/dialogue/ConditionEvaluator.lua`
#     - `src/dialogue/ConsequenceHandler.lua`
#  - **Files to modify:**
#     - `src/dialogue/DialogueData.lua`: Add `conditions` and `consequences` fields to `ConversationNode` structure.
#  - **Key functions to implement:**
#     - `ConditionEvaluator.evaluate(conditions, player, gameState, npcMemory)`: Implement logic for basic condition types (e.g., `hasItem`, `playerStat`, `questProgress`, `npcMemory`).
#     - `ConsequenceHandler.execute(consequences, player, gameState, npcMemory)`: Implement logic for basic consequence types (e.g., `startQuest`, `addItem`, `modifyRelationship`, `setGameStateFlag`).
#  - **Dependencies:** Phase 1 (for `DialogueData` structure)
#
# **Phase 3: Dialogue Manager - Core Logic (Days 7-9)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/dialogue/DialogueManager.lua`
#  - **Files to modify:**
#     - `src/dialogue/DialogueData.lua`: Add `is_repeatable` and `next_node_id_default` fields to `ConversationNode`.
#  - **Key functions to implement:**
#     - `DialogueManager.loadConversationData(npcId)`: Load and cache conversation data using `DialogueParser`.
#     - `DialogueManager.validateConversationTree(conversationData)`: Call `DialogueParser.validateStructure`.
#     - `DialogueManager.startConversation(npcId, player)`: Initialize `activeConversation` and set the initial node.
#     - `DialogueManager.getCurrentDialogueNode()`: Return the current node data.
#     - `DialogueManager.advanceDialogue()`: Move to the next node based on `next_node_id_default` or player choice.
#     - `DialogueManager.endConversation()`: Reset `activeConversation`.
#  - **Dependencies:** Phase 1, Phase 2
#
# **Phase 4: Dialogue UI - Display and Basic Input (Days 10-12)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/dialogue/DialogueUI.lua`
#  - **Files to modify:**
#     - `conf.lua`: Ensure necessary font loading is configured.
#  - **Key functions to implement:**
#     - `DialogueUI.showDialogueWindow(nodeData)`: Display the dialogue window, portrait, and text.
#     - `DialogueUI.updateTextDisplay(text, animationSpeed)`: Implement text reveal animation.
#     - `DialogueUI.displayChoices(choices)`: Render player choice buttons.
#     - `DialogueUI.hideDialogueWindow()`: Close the dialogue window.
#     - `DialogueUI.handleInput(input)`: Capture player input for advancing text or selecting choices.
#  - **Dependencies:** Phase 3 (for `DialogueManager` to provide data)
#
# **Phase 5: Dialogue Manager - Choice Handling and Integration (Days 13-15)**
#  - **Priority:** Critical
#  - **Files to modify:**
#     - `src/dialogue/DialogueManager.lua`: Implement `selectPlayerChoice`.
#     - `src/dialogue/DialogueUI.lua`: Modify `handleInput` to communicate choice selection to `DialogueManager`.
#  - **Key functions to implement:**
#     - `DialogueManager.selectPlayerChoice(choiceIndex)`:
#         - Get selected choice data.
#         - Use `ConditionEvaluator` to check choice visibility.
#         - If visible, execute `ConsequenceHandler` actions.
#         - Set `currentNodeId` based on `next_node_id`.
#         - Call `advanceDialogue`.
#     - `DialogueUI.handleInput`: Send selected choice index to `DialogueManager.selectPlayerChoice`.
#  - **Dependencies:** Phase 2, Phase 3, Phase 4
#
# **Phase 6: NPC Interaction Trigger (Days 16-18)**
#  - **Priority:** High
#  - **Files to create:**
#     - `src/dialogue/NPCInteractionTrigger.lua`
#  - **Files to modify:**
#     - `main.lua` (or equivalent game loop file): Integrate `NPCInteractionTrigger.update`.
#  - **Key functions to implement:**
#     - `NPCInteractionTrigger.update(player, npcs)`: Iterate through NPCs, check proximity.
#     - `NPCInteractionTrigger.isPlayerNearNPC(player, npc)`: Calculate distance.
#     - `NPCInteractionTrigger.showInteractionPrompt(npc)`: Display a visual prompt.
#     - `NPCInteractionTrigger.hideInteractionPrompt(npc)`: Hide the prompt.
#  - **Dependencies:** Phase 3 (for `DialogueManager.startConversation`)
#
# **Phase 7: Integration with Game Systems (Days 19-21)**
#  - **Priority:** High
#  - **Files to modify:**
#     - `src/dialogue/ConditionEvaluator.lua`: Add more robust checks for Quest System, Inventory System, Player Stats, Game State.
#     - `src/dialogue/ConsequenceHandler.lua`: Add more robust actions for Quest System, Inventory System, Game State.
#     - `src/dialogue/DialogueManager.lua`: Implement saving/loading of `npcMemory` (requires integration with Save System).
#     - `src/dialogue/DialogueUI.lua`: Integrate with Audio System for voice lines/SFX, and Input Handling for player actions.
#  - **Key functions to implement:**
#     - Extend `ConditionEvaluator.evaluate` and `ConsequenceHandler.execute` to interact with external systems.
#     - Implement `DialogueManager` methods for saving/loading `npcMemory`.
#     - Integrate `DialogueUI` input handling with the main input system.
#  - **Dependencies:** Phase 2, Phase 5, Phase 6, and existing game systems (Quest, Inventory, Player Stats, Game State, Audio, Save, Input).
#
# ## Integration Instructions
#
# *   **Where to call new code:**
#     *   `main.lua` (or equivalent):
#         *   `require` statements for all dialogue modules.
#         *   Initialize `DialogueManager`, `DialogueUI`, `NPCInteractionTrigger`.
#         *   In `love.update(dt)`: Call `NPCInteractionTrigger.update(player, npcs)`.
#         *   In `love.keypressed(key)` or `love.mousepressed(x, y, button)`: Pass input to `DialogueUI.handleInput(key)` if a conversation is active.
#         *   In `love.draw()`: Call `DialogueUI.draw()` if a conversation is active.
#     *   `NPCInteractionTrigger.lua`:
#         *   When player is near an NPC and interacts (e.g., presses 'E'), call `DialogueManager.startConversation(npcId, player)`.
#     *   `DialogueManager.lua`:
#         *   When `startConversation` is called, load data and then call `DialogueUI.showDialogueWindow(getCurrentDialogueNode())`.
#         *   When `selectPlayerChoice` is called, after processing, call `DialogueUI.showDialogueWindow(getCurrentDialogueNode())` or `endConversation()`.
#         *   When `endConversation` is called, call `DialogueUI.hideDialogueWindow()`.
#     *   `DialogueUI.lua`:
#         *   When player selects a choice, call `DialogueManager.selectPlayerChoice(choiceIndex)`.
#         *   When player presses a key to advance text, call `DialogueManager.advanceDialogue()`.
#         *   When player presses ESC, call `DialogueManager.endConversation()`.
# *   **Required imports:**
#     *   `require("src.dialogue.DialogueManager")`
#     *   `require("src.dialogue.DialogueParser")`
#     *   `require("src.dialogue.DialogueUI")`
#     *   `require("src.dialogue.ConditionEvaluator")`
#     *   `require("src.dialogue.ConsequenceHandler")`
#     *   `require("src.dialogue.NPCInteractionTrigger")`
#     *   `require("src.dialogue.DialogueData")`
# *   **Initialization:**
#     *   In `main.lua` (or equivalent):
#         ```lua
#         local dialogueManager = DialogueManager.new()
#         local dialogueUI = DialogueUI.new()
#         local npcInteractionTrigger = NPCInteractionTrigger.new()
#
#         -- Pass references where needed, e.g.:
#         dialogueManager:setUI(dialogueUI)
#         dialogueUI:setManager(dialogueManager)
#         npcInteractionTrigger:setDialogueManager(dialogueManager)
#         ```
# *   **Game loop integration:**
#     *   `love.update(dt)`:
#         ```lua
#         -- In main.lua
#         npcInteractionTrigger:update(player, npcs)
#         -- Potentially other dialogue manager updates if needed for timed events
#         ```
#     *   `love.draw()`:
#         ```lua
#         -- In main.lua
#         if dialogueManager:isConversationActive() then
#             dialogueUI:draw()
#         end
#         ```
#     *   Input Handling (`love.keypressed`, `love.mousepressed`):
#         ```lua
#         -- In main.lua
#         if dialogueManager:isConversationActive() then
#             dialogueUI:handleInput(key, x, y, button) -- Pass relevant input
#         end
#         ```
#
# ## Testing Requirements
#
# **DialogueParser:**
#  - **Unit tests:**
#     - `DialogueParser.parseFile`: Test with valid JSON, invalid JSON, non-existent file.
#     - `DialogueParser.validateStructure`: Test with valid conversation data, missing required fields, invalid node IDs, circular references.
#     - `DialogueParser.buildConversationTree`: Test with a simple linear conversation, a branching conversation, and a conversation with conditions.
#  - **Integration tests:**
#     - Load a sample dialogue file (`merchant_bob.json`) and verify it's parsed into the correct `ConversationTree` structure.
#  - **Manual testing steps:**
#     - Create a simple JSON dialogue file.
#     - Call `DialogueParser.parseFile` and `DialogueParser.buildConversationTree`.
#     - Inspect the resulting `ConversationTree` data structure for correctness.
#
# **ConditionEvaluator:**
#  - **Unit tests:**
#     - `ConditionEvaluator.evaluate`: Test with `hasItem` (item present/absent), `playerStat` (various operators and values), `questProgress` (different statuses), `npcMemory` (key present/absent, correct/incorrect value).
#  - **Integration tests:**
#     - Create a `ConversationNode` with various conditions.
#     - Mock `player`, `gameState`, and `npcMemory` objects with specific states.
#     - Call `ConditionEvaluator.evaluate` and verify the correct boolean result.
#  - **Manual testing steps:**
#     - Create a `ConversationNode` with a condition (e.g., `playerStat.strength > 10`).
#     - Set up a player object with `strength = 15`.
#     - Call `ConditionEvaluator.evaluate` with this node's conditions and verify it returns `true`.
#     - Change player strength to `5` and verify it returns `false`.
#
# **ConsequenceHandler:**
#  - **Unit tests:**
#     - `ConsequenceHandler.execute`: Test with `startQuest`, `addItem`, `modifyRelationship`, `setGameStateFlag` and verify that the corresponding mock game systems are called with the correct parameters.
#  - **Integration tests:**
#     - Create a `ConversationNode` with several consequences.
#     - Mock the `QuestSystem`, `InventorySystem`, and `GameState` objects.
#     - Call `ConsequenceHandler.execute` and verify that the mock systems are updated as expected.
#  - **Manual testing steps:**
#     - Create a `ConversationNode` with a consequence (e.g., `addItem.itemId = "health_potion", quantity = 2`).
#     - Mock the `InventorySystem` to track added items.
#     - Call `ConsequenceHandler.execute` and verify that the `InventorySystem` reports adding 2 health potions.
#
# **DialogueManager:**
#  - **Unit tests:**
#     - `DialogueManager.loadConversationData`: Test loading for an existing NPC, non-existent NPC, and corrupted data.
#     - `DialogueManager.startConversation`: Verify `activeConversation` is initialized correctly.
#     - `DialogueManager.selectPlayerChoice`: Test selecting a valid choice, an invalid choice (out of bounds), a choice with unmet conditions, and a choice that leads to a new node.
#     - `DialogueManager.advanceDialogue`: Test advancing to the default next node.
#     - `DialogueManager.endConversation`: Verify `activeConversation` is cleared.
#  - **Integration tests:**
#     - Start a conversation with an NPC.
#     - Select a player choice that has consequences and leads to a new node.
#     - Verify that the consequences are executed (by checking mock systems) and the UI updates to the new dialogue node.
#     - Test exiting the conversation.
#  - **Manual testing steps:**
#     - Start a conversation with an NPC.
#     - Observe the initial dialogue text and portrait.
#     - Select a player choice.
#     - Verify that the dialogue text updates correctly, and if the choice had consequences, that they are reflected in the game state (e.g., a quest is started).
#     - Navigate through a few dialogue nodes.
#     - Exit the conversation and verify the UI is hidden.
#
# **DialogueUI:**
#  - **Unit tests:**
#     - `DialogueUI.showDialogueWindow`: Verify UI elements (window, portrait, text area, choice buttons) are rendered.
#     - `DialogueUI.updateTextDisplay`: Test text animation speed and completion.
#     - `DialogueUI.displayChoices`: Verify correct number and text of choices are displayed.
#     - `DialogueUI.hideDialogueWindow`: Verify UI elements are hidden.
#     - `DialogueUI.handleInput`: Test that correct actions are triggered based on input (e.g., advancing text, selecting a choice).
#  - **Integration tests:**
#     - Start a conversation via `DialogueManager`.
#     - Verify that `DialogueUI.showDialogueWindow` is called with correct data.
#     - Select a player choice and verify that `DialogueUI.handleInput` correctly signals the `DialogueManager`.
#     - Test exiting the conversation and verifying `DialogueUI.hideDialogueWindow` is called.
#  - **Manual testing steps:**
#     - Start a conversation.
#     - Observe the dialogue window, speaker portrait, and dialogue text.
#     - Verify the text appears with the intended animation.
#     - Check that player choices are displayed correctly.
#     - Use input to advance text and select choices.
#     - Exit the conversation and confirm the UI disappears.
#
# **NPCInteractionTrigger:**
#  - **Unit tests:**
#     - `NPCInteractionTrigger.isPlayerNearNPC`: Test with player at various distances from NPC (within range, at range, outside range).
#     - `NPCInteractionTrigger.update`: Test that prompts are shown/hidden correctly as the player enters/exits interaction range.
#  - **Integration tests:**
#     - Place the player near an NPC.
#     - Verify that `NPCInteractionTrigger.showInteractionPrompt` is called.
#     - Move the player away from the NPC.
#     - Verify that `NPCInteractionTrigger.hideInteractionPrompt` is called.
#     - While near the NPC, press the interaction key and verify that `DialogueManager.startConversation` is called with the correct NPC ID.
#  - **Manual testing steps:**
#     - Place the player character near an NPC.
#     - Observe if an interaction prompt appears above the NPC.
#     - Move the player away from the NPC and confirm the prompt disappears.
#     - Move back to the NPC and press the interaction key.
#     - Verify that a conversation starts with that NPC.
#
# ## File Structure
#
# ```
# [project_folder]/
# ├── src/
# │   ├── dialogue/
# │   │   ├── DialogueManager.lua
# │   │   ├── DialogueParser.lua
# │   │   ├── DialogueUI.lua
# │   │   ├── ConditionEvaluator.lua
# │   │   ├── ConsequenceHandler.lua
# │   │   ├── NPCInteractionTrigger.lua
# │   │   └── DialogueData.lua
# │   └── main.lua  -- (or equivalent game entry point)
# ├── assets/
# │   ├── dialogue/
# │   │   ├── npc_data/
# │   │   │   ├── merchant_bob.json
# │   │   │   └── quest_giver_alice.json
# │   │   └── portraits/
# │   │       ├── bob_portrait.png
# │   │       └── alice_portrait.png
# │   └── fonts/ -- (if needed for UI)
# └── conf.lua
# ```
#
# ---
# ap_review
# document_type='architecture_plan' review_output=ArchitectureReviewOutput(review_status='Approved', review_notes='', completeness_score=5, feasibility_score=5, simplicity_score=5) review_count=1 max_reviews_allowed=3
#
# ---
# fip_review
# document_type='feature_implementation_plan' review_output=FIPReviewOutput(review_status='Approved', review_notes='', completeness_score=5, implementation_score=5, alignment_score=5) review_count=1 max_reviews_allowed=3

# %%
print(
    parse_review_response(
        content="""
        ```json
{
  "review_status": "Approved",
  "completeness_score": 5,
  "implementation_score": 5,
  "alignment_score": 5,
  "review_notes": ""
}
```
        """, 
        review_type="fip")
)
# Out:
# review_status='Approved' review_notes='' completeness_score=5 implementation_score=5 alignment_score=5

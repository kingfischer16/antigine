# %% [markdown]
# # Testing graph and agent architecture

# %%
from langgraph.graph import StateGraph, END
from typing import Annotated, Literal, TypedDict
from pydantic import BaseModel, Field
import json
from langchain_core.messages import BaseMessage, SystemMessage, HumanMessage, ToolMessage, AIMessage
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_linkup import LinkupSearchTool
from langgraph.checkpoint.memory import InMemorySaver

from IPython.display import Image, Markdown, display
from uuid import uuid4

GEMINI_MODEL_NAME = "gemini-2.5-flash-lite-preview-06-17"
#GEMINI_MODEL_NAME = "gemini-2.5-flash"

# %%
model = ChatGoogleGenerativeAI(model=GEMINI_MODEL_NAME, temperature=0.0, thinking_budget=0)

# %% [markdown]
# ## Prompts

# %%
# Project-specific constants
ENGINE_OR_FRAMEWORK = "Love2D framework"
PROG_LANGUAGE = "Lua"

TECH_ARCHITECT_WRITER_SYSTEM_PROMPT = (
    "You are an expert technical architect in game development using the " + ENGINE_OR_FRAMEWORK
    + " with " + PROG_LANGUAGE + " as the programming language. Given the feature request below, "
    "create a high-level technical architecture following this exact structure:\n"
    "## System Overview\n"
    "Write 2-3 sentences summarizing what this system does and its main purpose.\n"
    "\n"
    "## Core Components\n"
    "For each major component include component name, purpose, key methods, and data structures.\n"
    "\n"
    "## Component Interactions\n"
    "Describe how components communicate with each other. Include component calls, data passed, and event flow as necessary.\n"
    "\n"
    "## File Organization\n"
    "List the specific files to create and what each contains.\n"
    "\n"
    "## Integration Points\n"
    "Specify how this connects to existing game systems (player stats, save system, input handling, etc.).\n"
    "\n"
    "Requirements:\n"
    "- Include all functionality mentioned in the feature request\n"
    "- Each component should have a single, clear responsibility\n"
    "- Use standard " + ENGINE_OR_FRAMEWORK + " patterns, files, and configurations\n"
    "- Specify data structures inline with best practices for the " + PROG_LANGUAGE + " language\n"
    "- Keep components loosely coupled with clear interfaces\n"
    "\n"
    "Do not include implementation details, specific code, or functionality not requested.\n"
    "-----\n"
)

TECH_ARCHITECT_REVIEWER_SYSTEM_PROMPT = (
    "You are an expert technical architect in game development using the " + ENGINE_OR_FRAMEWORK
    + " with " + PROG_LANGUAGE + " as the programming language. "
    "Review the technical architecture against the original feature request. Check each item below:\n"
    "\n"
    "**Completeness Check:**\n"
    " - Are all features from the request addressed in the architecture?\n"
    " - Does each component have a clear purpose and key methods listed?\n"
    " - Are component interactions and integrations clearly described?\n"
    "\n"
    "**Feasibility Check:**\n"
    " - Are the proposed components appropriate for the " + ENGINE_OR_FRAMEWORK + " and the " + PROG_LANGUAGE + " language?\n"
    " - Are the data structures feasible using " + PROG_LANGUAGE + " formats?\n"
    " - Are the component interactions realistic and efficient?\n"
    "\n"
    "**Simplicity Check:**\n"
    " - Is each component focused on a single responsibility?\n"
    " - Are components loosely coupled?\n"
    " - Is the architecture as simple as possible while meeting requirements?\n"
    "\n"
    "Your response must comply with this output structure:\n"
    " - 'review_status' (str): Approved or Needs Revision,\n"
    " - 'completeness_score' (int): [1-5, where 5 = all features covered],\n"
    " - 'feasibility_score' (int): [1-5, where 5 = fully feasible in " + ENGINE_OR_FRAMEWORK + "/" + PROG_LANGUAGE + "],\n"
    " - 'simplicity_score' (int): [1-5, where 5 = appropriately simple],\n"
    " - 'review_notes' (str): If Needs Revision: describe specific issues to fix. If Approved: leave empty string.\n"
    "\n"
    "Example output format:\n"
    "review_status: Approved\n"
    "completeness_score: 5\n"
    "feasibility_score: 4\n"
    "simplicity_score: 5\n"
    "review_notes: \n"
    "\n"
    "Only approve if ALL scores are 4 or greater. Otherwise mark as 'Needs Revision' and provide specific feedback.\n"
    "-----\n"
)

FIP_WRITER_SYSTEM_PROMPT = (
    "You are an expert game developer using the " + ENGINE_OR_FRAMEWORK + " with "
    + PROG_LANGUAGE + " as the programming language. Given the technical architecture below, "
    "create a feature implementation plan (FIP) following this exact structure:\n"
    "\n"
    "## Implementation Overview\n"
    "Write 2-3 sentences describing what will be implemented and the overall approach.\n"
    "\n"
    "## Implementation Phases\n"
    "Break work into phases. For each phase:\n"
    "\n"
    "**Phase [X]: [Name] (Days X-Y)**\n"
    " - **Priority:** Critical/High/Medium/Low\n"
    " - **Files to create:** [list specific " + PROG_LANGUAGE + " filenames]\n"
    " - **Files to modify:** [list existing files and what changes]\n"
    " - **Key functions to implement:** [function names with brief descriptions]\n"
    " - **Dependencies:** [what must be completed first]\n"
    "\n"
    "## Integration Instructions\n"
    " - **Where to call new code:** [specific files and functions]\n"
    " - **Required imports:** [require statements needed]\n"
    " - **Initialization:** [where to create instances]\n"
    " - **Game loop integration:** [update/draw call locations]\n"
    "\n"
    "## Testing Requirements\n"
    "For each major component:\n"
    " - **Unit tests:** [specific functions to test]\n"
    " - **Integration tests:** [end-to-end workflows to verify]\n"
    " - **Manual testing steps:** [how to verify functionality works]\n"
    "\n"
    "## File Structure\n"
    "```\n"
    "[project_folder]/\n"
    "├── [component1]\n"
    "├── [component2]\n"
    "└── data/\n"
    "    ├── [datafiles]\n"
    "```\n"
    "\n"
    "Requirements:\n"
    " - Include implementation steps for ALL components from the architecture\n"
    " - Specify exact function names and file locations\n"
    " - Provide concrete testing steps that can be executed\n"
    " - Include all integration points with existing systems\n"
    " - Order phases by dependencies (prerequisites first)\n"
    " - Each phase should take 1-3 days maximum\n"
    "\n"
    "Do not include actual code implementation - focus on what to build and how to integrate it.\n"
    "-----\n"
)

FIP_REVIEWER_SYSTEM_PROMPT = (
    "You are an expert game developer using the " + ENGINE_OR_FRAMEWORK + " with "
    + PROG_LANGUAGE + " as the programming language. Review the feature implementation "
    "plan (FIP) against the technical architecture. Check each item:\n"
    "\n"
    "**Completeness Check:**\n"
    " 1. Does each architecture component have implementation steps in the FIP?\n"
    " 2. Are all files to create/modify specified with names?\n"
    " 3. Are function names and integration points clearly stated?\n"
    " 4. Are testing requirements specified for each component?\n"
    " 5. Is the file structure/organization defined?\n"
    "\n"
    "**Implementation Quality Check:**\n"
    " 1. Are phases ordered by dependencies (no circular dependencies)?\n"
    " 2. Are phase durations realistic (1-3 days each)?\n"
    " 3. Are integration instructions specific (exact files/functions)?\n"
    " 4. Are testing steps actionable and concrete?\n"
    "\n"
    "**Architecture Alignment Check:**\n"
    " 1. Does the FIP address all components from the architecture?\n"
    " 2. Are the proposed functions aligned with architecture methods?\n"
    " 3. Are data structures and interactions preserved?\n"
    "\n"
    "Your response must comply with this output structure:\n"
    " - 'review_status' (int): Approved or Needs Revision,\n"
    " - 'completeness_score' (int): [1-5, where 5 = all architecture components covered],\n"
    " - 'implementation_score' (int): [1-5, where 5 = clear, actionable instructions],\n"
    " - 'alignment_score' (int): [1-5, where 5 = fully matches architecture],\n"
    " - 'review_notes' (str): If Needs Revision: describe specific issues to fix. If Approved: leave empty string.\n"
    "\n"
    "Example output format:\n"
    "review_status: Approved\n"
    "completeness_score: 5\n"
    "implementation_score: 4\n"
    "alignment_score: 5\n"
    "review_notes: \n"
    "\n"
    "Only approve if ALL scores are 4 or greater. Otherwise mark as 'Needs Revision' and provide specific feedback.\n"
    "-----\n"
)

# %% [markdown]
# ## State Classes

# %%
class ArchitectureReviewOutput(BaseModel):
    review_status: Literal["Approved", "Needs Revision"] = Field(description="Status of the review, either 'Approved' or 'Needs Revision'.", default="Needs Revision")
    review_notes: str = Field(description="Detailed feedback on the document being reviewed. If the document is approved, this should be an empty string.", default="")
    completeness_score: int = Field(ge=1, le=5, description="Score for completeness", default=1)
    feasibility_score: int = Field(ge=1, le=5, description="Score for feasibility", default=1)
    simplicity_score: int = Field(ge=1, le=5, description="Score for simplicity", default=1)

class FIPReviewOutput(BaseModel):
    review_status: Literal["Approved", "Needs Revision"] = Field(description="Status of the review, either 'Approved' or 'Needs Revision'.", default="Needs Revision")
    review_notes: str = Field(description="Detailed feedback on the document being reviewed. If the document is approved, this should be an empty string.", default="")
    completeness_score: int = Field(ge=1, le=5, description="Score for completeness", default=1)
    implementation_score: int = Field(ge=1, le=5, description="Score for implementation quality", default=1)
    alignment_score: int = Field(ge=1, le=5, description="Score for architecture alignment", default=1)

class Review(BaseModel):
    """Review ouptut format for the review agents."""
    document_type: Literal["architecture_plan", "feature_implementation_plan"]
    review_output: ArchitectureReviewOutput | FIPReviewOutput
    review_count: int = 0
    max_reviews_allowed: int = 3

class WorkflowState(BaseModel):
    """
    Represents the state of the total workflow. This is the highest level state.
    """
    feature_request: str= ""
    architecture_plan: str = ""
    feature_implementation_plan: str = ""
    ap_review: Review = Field(default_factory=lambda: Review(
        document_type="architecture_plan",
        review_output=ArchitectureReviewOutput(
            review_status="Needs Revision",
            review_notes="",
            completeness_score=1,
            feasibility_score=1,
            simplicity_score=1
        )
    ))
    fip_review: Review = Field(default_factory=lambda: Review(
        document_type="feature_implementation_plan",
        review_output=FIPReviewOutput(
            review_status="Needs Revision",
            review_notes="",
            completeness_score=1,
            implementation_score=1,
            alignment_score=1
        )
    ))

# %% [markdown]
# ## Nodes

# %%
def parse_review_response(content: str, review_type: str) -> ArchitectureReviewOutput | FIPReviewOutput:
    lines = content.strip().split('\n')
    data = {}
    
    for line in lines:
        if ':' in line:
            key, value = line.split(':', 1)
            key = key.strip().lower().replace(' ', '_').replace('"', "").replace("'", "")
            value = value.strip().replace('"', "").replace("'", "").replace(",", "")
            
            if key == 'review_status':
                data[key] = value
            elif key.endswith('_score'):
                data[key] = int(value) if value.isdigit() else 1
            elif key == 'review_notes':
                data[key] = value
            else:
                print(f"Unknown key: {key}, value: {value}")

    if review_type == "architecture":
        return ArchitectureReviewOutput(**data)
    else:
        return FIPReviewOutput(**data)

def tech_arch_writer_node(state: WorkflowState) -> dict:
    """
    Node to write the technical architecture.
    """
    # Create the system message with the prompt
    system_msg = SystemMessage(content=TECH_ARCHITECT_WRITER_SYSTEM_PROMPT)
    feature_content = f"Feature request:\n{state.feature_request}"
    
    # If you need tools, bind them to the model
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools = model #.bind_tools(tools)
    
    # Create messages list
    if state.ap_review.review_count > 0:
        previous_draft = f"\nThis is the previous draft of the architecture plan:\n{state.architecture_plan}\n\n"
        review_feedback = f"Review feedback to address:\n{state.ap_review.review_output.review_notes}\n\n"
        feature_msg = HumanMessage(content=feature_content + previous_draft + review_feedback)
    else:
        feature_msg = HumanMessage(content=feature_content)
    
    messages = [system_msg, feature_msg]
    
    # Invoke the model
    response = model_with_tools.invoke(messages)

    if hasattr(response, 'usage_metadata') and response.usage_metadata:
        print(f"Tech Arch Writer - Input tokens: {response.usage_metadata.get('input_tokens', 'N/A')}")
        print(f"Tech Arch Writer - Output tokens: {response.usage_metadata.get('output_tokens', 'N/A')}")
        print(f"Tech Arch Writer - Total tokens: {response.usage_metadata.get('total_tokens', 'N/A')}")
    
    # Return the update to state
    return {"architecture_plan": response.content}

def tech_arch_validator_node(state: WorkflowState) -> dict:
    """
    Node to validate the technical architecture.
    """
    print(f"Starting architecture validation...")
    # Create the system message
    system_msg = SystemMessage(content=TECH_ARCHITECT_REVIEWER_SYSTEM_PROMPT)
    feature_req = f"Original feature request:\n{state.feature_request}\n-----\n"
    ap_draft = f"Technical architecture to review:\n{state.architecture_plan}\n-----\n"
    task_msg = HumanMessage(content=feature_req + ap_draft)
    
    # Use structured output to ensure proper formatting
    model_with_structured_output = model #.with_structured_output(ArchitectureReviewOutput)
    
    # Add tools if needed (bind tools before structured output)
    #tools = [LinkupSearchTool()]
    model_with_tools_and_structure = model_with_structured_output#.bind_tools(tools)
    
    # Invoke model
    response = model_with_tools_and_structure.invoke([system_msg, task_msg])
    parsed_response = parse_review_response(response.content, "architecture")

    if hasattr(response, 'usage_metadata') and response.usage_metadata:
        print(f"Tech Arch Reviewer - Input tokens: {response.usage_metadata.get('input_tokens', 'N/A')}")
        print(f"Tech Arch Reviewer - Output tokens: {response.usage_metadata.get('output_tokens', 'N/A')}")
        print(f"Tech Arch Reviewer - Total tokens: {response.usage_metadata.get('total_tokens', 'N/A')}")
    # response is now a ReviewOutput object, no parsing needed!
    updated_review = Review(
        document_type="architecture_plan",
        review_output=parsed_response,
        review_count=state.ap_review.review_count + 1,
        max_reviews_allowed=state.ap_review.max_reviews_allowed
    )
    if parsed_response.review_status == "Needs Revision":
        print(f"Architecture review notes: {parsed_response.review_notes}")
    
    return {"ap_review": updated_review}

def feature_impl_writer(state: WorkflowState) -> dict:
    """
    Node to write the feature implementation plan. Includes the subgraph to both write the plan and
    call tools.
    """
    system_msg = SystemMessage(content=FIP_WRITER_SYSTEM_PROMPT)
    task_content = f"Technical architecture:\n{state.architecture_plan}"
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools = model#.bind_tools(tools)

    if state.fip_review.review_count > 0:
        previous_draft = f"Previously submitted draft of the feature implementation plan:\n{state.feature_implementation_plan}\n\n"
        review_feedback = f"Please address this feedback in your next draft of the feature implementation plan:\n{state.fip_review.review_output.review_notes}\n\n"
        task_msg = HumanMessage(content=task_content + previous_draft + review_feedback)
    else:
        task_msg = HumanMessage(content=task_content)
    
    messages = [system_msg, task_msg]
    # Invoke the model
    response = model_with_tools.invoke(messages)
    return {"feature_implementation_plan": response.content}

def feature_impl_validator_node(state: WorkflowState) -> dict:
    """
    Node to validate the feature implementation plan. Includes the subgraph to both review the plan and
    call tools.
    """
    system_msg = SystemMessage(content=FIP_REVIEWER_SYSTEM_PROMPT)
    ap_draft = f"Technical architecture:\n{state.architecture_plan}\n-----\n"
    fip_draft = f"Feature implementation plan to review:\n{state.feature_implementation_plan}\n-----\n"
    task_msg = HumanMessage(content=ap_draft + fip_draft)
    model_with_structured_output = model #.with_structured_output(FIPReviewOutput)
    #tools = [LinkupSearchTool()]  # Add your tools here
    model_with_tools_and_structure = model_with_structured_output#.bind_tools(tools)
    response = model_with_tools_and_structure.invoke([system_msg, task_msg])
    parsed_response = parse_review_response(response.content, "fip")
    updated_review = Review(
        document_type="feature_implementation_plan",
        review_output=parsed_response,
        review_count=state.fip_review.review_count + 1,
        max_reviews_allowed=state.fip_review.max_reviews_allowed
    )
    if parsed_response.review_status == "Needs Revision":
        print(f"Feature implementation plan review notes: {parsed_response.review_notes}")
    return {"fip_review": updated_review}

def tech_arch_approval(state: WorkflowState) -> str:
    """
    Node to approve the technical architecture.
    """
    if state.ap_review.review_count >= state.ap_review.max_reviews_allowed:
        return "Review limit reached"
    if (
        (state.ap_review.review_output.completeness_score >= 4) &
        (state.ap_review.review_output.feasibility_score >= 4) &
        (state.ap_review.review_output.simplicity_score >= 4)
     ):
        return "Approved"
    else:
        return "Needs Revision"

def feature_impl_approval(state: WorkflowState) -> str:
    """
    Node to approve the feature implementation plan.
    """
    if state.fip_review.review_count >= state.fip_review.max_reviews_allowed:
        return "Review limit reached"
    if (
        (state.fip_review.review_output.completeness_score >= 4) &
        (state.fip_review.review_output.implementation_score >= 4) &
        (state.fip_review.review_output.alignment_score >= 4)
     ):
        return "Approved"
    else:
        return "Needs Revision"

# %% [markdown]
# ## Graphs

# %%
# Create the workflow graph
workflow_builder = StateGraph(WorkflowState)

# Add nodes
workflow_builder.add_node("tech_arch_writer", tech_arch_writer_node)
workflow_builder.add_node("tech_arch_validator", tech_arch_validator_node)
workflow_builder.add_node("feature_impl_writer", feature_impl_writer)
workflow_builder.add_node("feature_impl_validator", feature_impl_validator_node)

# Add edges
workflow_builder.add_edge("tech_arch_writer", "tech_arch_validator")
workflow_builder.add_edge("feature_impl_writer", "feature_impl_validator")

# Add control flow
workflow_builder.set_entry_point("tech_arch_writer")
workflow_builder.add_conditional_edges(
    "tech_arch_validator",
    tech_arch_approval,
    {
        "Approved": "feature_impl_writer",
        "Needs Revision": "tech_arch_writer",
        "Review limit reached": END
    }
)
workflow_builder.add_conditional_edges(
    "feature_impl_validator",
    feature_impl_approval,
    {
        "Approved": END,
        "Needs Revision": END, #"feature_impl_writer",
        "Review limit reached": END
    }
)

# Compile the graph
workflow_graph = workflow_builder.compile(
    name="Feature Development Workflow"
)

# %%
CASE = 2

if CASE == 1:
    response = workflow_graph.invoke({"feature_request": "Implement a dash feature for the first person movement controller."})
elif CASE == 2:
    response = workflow_graph.invoke({"feature_request": """Overview
Implement a comprehensive player inventory system that allows players to collect, manage, and use items throughout the game. This system should support both consumable and equipment items with a user-friendly interface.
Functional Requirements
Core Inventory Management

Grid-based storage: 20-slot inventory grid (4x5 layout) where each item occupies one slot
Item stacking: Consumable items stack up to 99 per slot, equipment items don't stack
Item sorting: Automatic sorting option that groups items by type (consumables, weapons, armor, misc)
Item filtering: Search functionality to quickly locate specific items by name or type

Item Types and Properties

Consumable Items: Health potions, mana potions, food items with immediate use effects
Equipment Items: Weapons, armor pieces, accessories that modify player stats when equipped
Quest Items: Special items that cannot be dropped or sold, marked with unique visual indicator
Crafting Materials: Basic materials used in future crafting system (prepare data structure)

User Interface

Inventory Window: Accessible via 'I' key, displays item grid with item icons and quantity
Item Tooltips: Hover over items to show name, description, stats, and value
Context Menu: Right-click items for options (use, drop, examine)
Drag & Drop: Click and drag items to rearrange inventory slots
Equipment Slots: Separate UI panel showing currently equipped weapon and armor

Item Acquisition & Removal

Item Pickup: Players walk over dropped items to automatically collect them
Item Dropping: Drop items from inventory to the game world at player location
Item Usage: Consumables apply effects immediately and are removed from inventory
Equipment: Click equipment items to equip/unequip, replacing current equipment

Technical Requirements
Data Persistence

Save/load inventory state between game sessions
Maintain item properties and quantities accurately
Handle equipped items persistence

Performance Constraints

Inventory operations should not cause frame drops
Support up to 1000 different item types in game data
Efficient item lookup and manipulation algorithms

Integration Points

Player Stats System: Equipment items modify player health, damage, speed stats
Game World: Items can be dropped and picked up from the environment
Future Systems: Data structure should accommodate future crafting and trading systems

User Experience Goals

Intuitive drag-and-drop interface similar to popular RPG games
Clear visual feedback for all inventory operations
Responsive controls with no input lag
Consistent visual design matching game's art style

Success Criteria

Players can successfully manage 20+ items without confusion
All inventory operations complete within 50ms
No item duplication or loss bugs
Save/load maintains exact inventory state
UI remains usable at all supported screen resolutions (800x600 to 1920x1080)"""})
# Out:
# Tech Arch Writer - Input tokens: 803
# Tech Arch Writer - Output tokens: 2687
# Tech Arch Writer - Total tokens: 3490
# Starting architecture validation...
# ```json
# {
#   "review_status": "Approved",
#   "completeness_score": 5,
#   "feasibility_score": 5,
#   "simplicity_score": 5,
#   "review_notes": ""
# }
# ```
# review_status='Approved' review_notes='' completeness_score=5 feasibility_score=5 simplicity_score=5
# Tech Arch Reviewer - Input tokens: 3635
# Tech Arch Reviewer - Output tokens: 59
# Tech Arch Reviewer - Total tokens: 3694
# ```json
# {
#   "review_status": "Approved",
#   "completeness_score": 5,
#   "implementation_score": 5,
#   "alignment_score": 5,
#   "review_notes": ""
# }
# ```
# review_status='Approved' review_notes='' completeness_score=5 implementation_score=5 alignment_score=5

# %%
for k,v in response.items():
    print(f"\n---\n{k}")
    print(v)
# Out:
# ---
# feature_request
# Overview
# Implement a comprehensive player inventory system that allows players to collect, manage, and use items throughout the game. This system should support both consumable and equipment items with a user-friendly interface.
# Functional Requirements
# Core Inventory Management
#
# Grid-based storage: 20-slot inventory grid (4x5 layout) where each item occupies one slot
# Item stacking: Consumable items stack up to 99 per slot, equipment items don't stack
# Item sorting: Automatic sorting option that groups items by type (consumables, weapons, armor, misc)
# Item filtering: Search functionality to quickly locate specific items by name or type
#
# Item Types and Properties
#
# Consumable Items: Health potions, mana potions, food items with immediate use effects
# Equipment Items: Weapons, armor pieces, accessories that modify player stats when equipped
# Quest Items: Special items that cannot be dropped or sold, marked with unique visual indicator
# Crafting Materials: Basic materials used in future crafting system (prepare data structure)
#
# User Interface
#
# Inventory Window: Accessible via 'I' key, displays item grid with item icons and quantity
# Item Tooltips: Hover over items to show name, description, stats, and value
# Context Menu: Right-click items for options (use, drop, examine)
# Drag & Drop: Click and drag items to rearrange inventory slots
# Equipment Slots: Separate UI panel showing currently equipped weapon and armor
#
# Item Acquisition & Removal
#
# Item Pickup: Players walk over dropped items to automatically collect them
# Item Dropping: Drop items from inventory to the game world at player location
# Item Usage: Consumables apply effects immediately and are removed from inventory
# Equipment: Click equipment items to equip/unequip, replacing current equipment
#
# Technical Requirements
# Data Persistence
#
# Save/load inventory state between game sessions
# Maintain item properties and quantities accurately
# Handle equipped items persistence
#
# Performance Constraints
#
# Inventory operations should not cause frame drops
# Support up to 1000 different item types in game data
# Efficient item lookup and manipulation algorithms
#
# Integration Points
#
# Player Stats System: Equipment items modify player health, damage, speed stats
# Game World: Items can be dropped and picked up from the environment
# Future Systems: Data structure should accommodate future crafting and trading systems
#
# User Experience Goals
#
# Intuitive drag-and-drop interface similar to popular RPG games
# Clear visual feedback for all inventory operations
# Responsive controls with no input lag
# Consistent visual design matching game's art style
#
# Success Criteria
#
# Players can successfully manage 20+ items without confusion
# All inventory operations complete within 50ms
# No item duplication or loss bugs
# Save/load maintains exact inventory state
# UI remains usable at all supported screen resolutions (800x600 to 1920x1080)
#
# ---
# architecture_plan
# ## System Overview
# The Player Inventory System manages all items a player possesses, allowing for collection, organization, and usage. It supports various item types, including consumables and equipment, with a user-friendly interface for interaction and seamless integration with other game mechanics.
#
# ## Core Components
#
# *   **InventoryManager**
#     *   **Purpose:** The central hub for all inventory operations. It manages the inventory grid, item stacking, sorting, filtering, and persistence.
#     *   **Key Methods:**
#         *   `addItem(itemData, quantity)`: Adds an item to the inventory.
#         *   `removeItem(slotIndex, quantity)`: Removes a specified quantity of an item from a slot.
#         *   `moveItem(fromSlot, toSlot)`: Swaps items between two slots.
#         *   `sortInventory()`: Sorts items based on predefined criteria.
#         *   `filterInventory(query)`: Filters items based on a search query.
#         *   `saveInventory()`: Serializes and saves the current inventory state.
#         *   `loadInventory(savedData)`: Deserializes and loads inventory state.
#         *   `getItemInSlot(slotIndex)`: Retrieves the item data for a given slot.
#         *   `findEmptySlot()`: Locates the next available empty slot.
#     *   **Data Structures:**
#         *   `inventorySlots`: A table representing the 20 inventory slots. Each slot can be `nil` or contain a table with:
#             *   `itemData`: Reference to the item's definition (from `ItemDatabase`).
#             *   `quantity`: The current quantity of the item in the slot (for stackable items).
#         *   `equippedItems`: A table mapping equipment slot types (e.g., "weapon", "armor") to the `itemData` and `quantity` of the equipped item.
#
# *   **ItemDatabase**
#     *   **Purpose:** Stores definitions for all possible items in the game.
#     *   **Key Methods:**
#         *   `getItemDefinition(itemID)`: Retrieves the full definition of an item by its ID.
#         *   `getAllItemDefinitions()`: Returns all item definitions.
#     *   **Data Structures:**
#         *   `items`: A table where keys are item IDs and values are tables containing item properties:
#             *   `id`: Unique item identifier.
#             *   `name`: Display name of the item.
#             *   `description`: Detailed description.
#             *   `icon`: Path to the item's icon asset.
#             *   `type`: "consumable", "equipment", "quest", "material".
#             *   `stackable`: Boolean, true if the item can stack.
#             *   `maxStack`: Maximum quantity for stackable items (default 99).
#             *   `useEffect`: Function or identifier for consumable effects.
#             *   `equipmentSlot`: For equipment, the slot it occupies (e.g., "weapon", "chest").
#             *   `statsModifier`: For equipment, a table of stat changes (e.g., `{ health = 10, damage = 5 }`).
#             *   `isQuestItem`: Boolean, true for quest items.
#             *   `value`: Gold value for trading.
#             *   `craftingMaterials`: For materials, a list of associated crafting recipes or uses.
#
# *   **InventoryUI**
#     *   **Purpose:** Handles the visual representation and user interaction of the inventory window and equipment slots.
#     *   **Key Methods:**
#         *   `drawInventory(inventorySlots)`: Renders the inventory grid, item icons, and quantities.
#         *   `drawEquipmentSlots(equippedItems)`: Renders the currently equipped items.
#         *   `showTooltip(itemData)`: Displays detailed information when hovering over an item.
#         *   `hideTooltip()`: Hides the tooltip.
#         *   `handleInput(event)`: Processes mouse and keyboard input for drag-and-drop, context menus, and opening/closing the inventory.
#         *   `showContextMenu(itemData, slotIndex)`: Displays context menu options.
#         *   `hideContextMenu()`: Hides the context menu.
#     *   **Data Structures:**
#         *   `inventoryGridRect`: Defines the screen area for the inventory grid.
#         *   `slotSize`: Dimensions of each inventory slot.
#         *   `tooltipData`: Stores information for the currently displayed tooltip.
#         *   `contextMenuData`: Stores information for the currently displayed context menu.
#
# *   **ItemPickupHandler**
#     *   **Purpose:** Detects when the player is near a dropped item in the game world and initiates pickup.
#     *   **Key Methods:**
#         *   `checkPickup(playerPos, droppedItems)`: Checks for player proximity to dropped items.
#         *   `triggerPickup(itemData, quantity, droppedItemEntity)`: Initiates the item pickup process.
#     *   **Data Structures:**
#         *   `droppedItems`: A list of tables, each representing an item dropped in the world, including its `itemData`, `quantity`, and `worldPosition`.
#
# *   **ItemDropHandler**
#     *   **Purpose:** Handles the logic for dropping items from the inventory into the game world.
#     *   **Key Methods:**
#         *   `dropItem(itemData, quantity, playerPos)`: Creates a new dropped item entity in the game world.
#     *   **Data Structures:**
#         *   `droppedItemEntity`: A reference to the visual representation of the item in the game world.
#
# *   **ItemUsageHandler**
#     *   **Purpose:** Manages the application of effects for consumable items.
#     *   **Key Methods:**
#         *   `useItem(itemData, slotIndex)`: Applies the item's effect and removes it from inventory.
#     *   **Data Structures:**
#         *   `itemEffects`: A mapping of `itemData.useEffect` identifiers to specific game logic functions.
#
# ## Component Interactions
#
# 1.  **Opening Inventory:**
#     *   `InputHandler` detects the 'I' key press.
#     *   `InputHandler` calls `InventoryUI.toggleInventoryVisibility()`.
#     *   `InventoryUI` requests the current inventory state from `InventoryManager`.
#     *   `InventoryUI` draws the inventory grid using data from `InventoryManager.inventorySlots`.
#
# 2.  **Item Pickup:**
#     *   `GameLoop` (or `PlayerController`) periodically calls `ItemPickupHandler.checkPickup(player.position, World.droppedItems)`.
#     *   If a pickup is detected, `ItemPickupHandler.triggerPickup(itemData, quantity, droppedItemEntity)` is called.
#     *   `ItemPickupHandler` calls `InventoryManager.addItem(itemData, quantity)`.
#     *   If `addItem` is successful, `ItemPickupHandler` signals the `World` to remove the `droppedItemEntity`.
#
# 3.  **Item Dropping:**
#     *   `InventoryUI` detects a drag-and-drop operation ending outside the inventory grid or a "drop" action from the context menu.
#     *   `InventoryUI` calls `ItemDropHandler.dropItem(itemData, quantity, player.position)`.
#     *   `ItemDropHandler` calls `InventoryManager.removeItem(slotIndex, quantity)`.
#     *   `ItemDropHandler` creates a new dropped item entity in the `World`.
#
# 4.  **Item Usage:**
#     *   `InventoryUI` detects a "use" action from the context menu or a direct click on a consumable.
#     *   `InventoryUI` calls `ItemUsageHandler.useItem(itemData, slotIndex)`.
#     *   `ItemUsageHandler` calls `ItemDatabase.getItemDefinition(itemData.id)` to get the effect.
#     *   `ItemUsageHandler` executes the `useEffect` (e.g., calls `PlayerStatsSystem.modifyHealth(amount)`).
#     *   `ItemUsageHandler` calls `InventoryManager.removeItem(slotIndex, 1)`.
#
# 5.  **Item Equipping/Unequipping:**
#     *   `InventoryUI` detects an "equip" action from the context menu or a drag-and-drop to an equipment slot.
#     *   `InventoryUI` calls `InventoryManager.getItemInSlot(fromSlot)` to get the item to equip.
#     *   `InventoryManager` checks if an item is already in the target equipment slot. If so, it calls `InventoryManager.moveItem(fromSlot, toSlot)` to unequip the current item and place it back in the inventory.
#     *   `InventoryManager` updates `equippedItems` with the new item.
#     *   `InventoryManager` calls `PlayerStatsSystem.applyEquipmentStats(itemData.statsModifier)` or `PlayerStatsSystem.removeEquipmentStats(previousItemData.statsModifier)`.
#
# 6.  **Sorting/Filtering:**
#     *   `InventoryUI` detects a sort or filter action.
#     *   `InventoryUI` calls `InventoryManager.sortInventory()` or `InventoryManager.filterInventory(query)`.
#     *   `InventoryManager` manipulates its `inventorySlots` data.
#     *   `InventoryUI` requests the updated `inventorySlots` from `InventoryManager` and redraws.
#
# 7.  **Data Persistence:**
#     *   `GameManager` (or similar) calls `InventoryManager.saveInventory()` during a save event.
#     *   `InventoryManager` serializes `inventorySlots` and `equippedItems` and passes to `SaveSystem`.
#     *   `GameManager` calls `InventoryManager.loadInventory(savedData)` during a load event.
#     *   `SaveSystem` retrieves data and passes it to `InventoryManager`.
#
# ## File Organization
#
# *   `src/inventory/`
#     *   `InventoryManager.lua`: Core inventory logic.
#     *   `ItemDatabase.lua`: Item definitions and retrieval.
#     *   `InventoryUI.lua`: User interface rendering and input handling for inventory.
#     *   `ItemPickupHandler.lua`: Logic for picking up items from the world.
#     *   `ItemDropHandler.lua`: Logic for dropping items into the world.
#     *   `ItemUsageHandler.lua`: Logic for using consumable items.
#     *   `InventoryConstants.lua`: Constants like grid size, slot dimensions, etc.
# *   `assets/icons/items/`: Directory for item icon images.
# *   `data/items.json` (or `.lua`): External file for item definitions, loaded by `ItemDatabase`.
#
# ## Integration Points
#
# *   **Player Stats System:**
#     *   `InventoryManager` calls `PlayerStatsSystem.modifyHealth()`, `PlayerStatsSystem.modifyDamage()`, etc., when equipment is equipped/unequipped.
#     *   `ItemUsageHandler` calls `PlayerStatsSystem.modifyHealth()`, `PlayerStatsSystem.modifyMana()`, etc., when consumables are used.
# *   **Game World:**
#     *   `ItemPickupHandler` interacts with entities representing dropped items in the world.
#     *   `ItemDropHandler` creates new entities in the world for dropped items.
#     *   `PlayerController` provides player position for pickup and drop operations.
# *   **Input Handling:**
#     *   `InputHandler` (or `PlayerController`) detects key presses ('I') and mouse events (clicks, drags) and forwards them to `InventoryUI`.
# *   **Save System:**
#     *   `InventoryManager` serializes its state (`inventorySlots`, `equippedItems`) and passes it to the `SaveSystem` for storage.
#     *   `InventoryManager` receives deserialized data from the `SaveSystem` to restore its state.
# *   **Crafting System (Future):**
#     *   `ItemDatabase` will store crafting recipes and material requirements.
#     *   `InventoryManager` will be queried for available materials.
# *   **Trading System (Future):**
#     *   `InventoryManager` will provide item data for trading.
#     *   `ItemDatabase` will provide item values.
# *   **UI Manager:**
#     *   `InventoryUI` will be managed by a central UI manager for drawing order and visibility.
#
# ---
# feature_implementation_plan
# ## Implementation Overview
# This plan outlines the implementation of a comprehensive Player Inventory System in Love2D. The system will allow players to collect, manage, and use items, featuring a visual inventory interface, item pickup/drop mechanics, and integration with player stats and game world elements. The approach will be phased, starting with core data management and progressing to UI and interaction logic.
#
# ## Implementation Phases
#
# **Phase 1: Item Database and Core Inventory Management (Days 1-3)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/inventory/ItemDatabase.lua`
#     - `src/inventory/InventoryManager.lua`
#     - `src/inventory/InventoryConstants.lua`
#     - `data/items.json`
#  - **Files to modify:**
#     - `main.lua` (for initial setup and requiring modules)
#  - **Key functions to implement:**
#     - `ItemDatabase.getItemDefinition(itemID)`: Retrieves item data from `data/items.json`.
#     - `ItemDatabase.getAllItemDefinitions()`: Loads all item definitions.
#     - `InventoryManager.addItem(itemData, quantity)`: Adds items, handles stacking and max stack.
#     - `InventoryManager.removeItem(slotIndex, quantity)`: Removes items, handles partial removal.
#     - `InventoryManager.getItemInSlot(slotIndex)`: Returns item data for a slot.
#     - `InventoryManager.findEmptySlot()`: Finds the next available slot.
#     - `InventoryManager.inventorySlots`: Initialize as a table of 20 `nil` values.
#     - `InventoryManager.equippedItems`: Initialize as an empty table.
#  - **Dependencies:** None.
#
# **Phase 2: Basic Inventory UI and Input Handling (Days 4-6)**
#  - **Priority:** Critical
#  - **Files to create:**
#     - `src/inventory/InventoryUI.lua`
#  - **Files to modify:**
#     - `main.lua` (to require `InventoryUI` and `InventoryManager`)
#     - `src/input/InputHandler.lua` (assuming this exists, to add inventory toggle)
#  - **Key functions to implement:**
#     - `InventoryUI.new(inventoryManager)`: Constructor to hold reference to `InventoryManager`.
#     - `InventoryUI.toggleInventoryVisibility()`: Toggles the inventory window's display state.
#     - `InventoryUI.drawInventory(inventorySlots)`: Renders the inventory grid, item icons, and quantities.
#     - `InventoryUI.handleInput(event)`: Processes key presses (e.g., 'I' to toggle) and mouse clicks within the inventory area.
#     - `InventoryUI.inventoryGridRect`, `InventoryUI.slotSize`: Define UI layout.
#  - **Dependencies:** Phase 1 (InventoryManager).
#
# **Phase 3: Item Pickup and Drop Mechanics (Days 7-9)**
#  - **Priority:** High
#  - **Files to create:**
#     - `src/inventory/ItemPickupHandler.lua`
#     - `src/inventory/ItemDropHandler.lua`
#  - **Files to modify:**
#     - `main.lua` (to require new handlers)
#     - `src/player/PlayerController.lua` (or equivalent, to provide player position and trigger pickup checks)
#     - `src/world/World.lua` (or equivalent, to manage dropped item entities)
#  - **Key functions to implement:**
#     - `ItemPickupHandler.checkPickup(playerPos, droppedItems)`: Iterates through `droppedItems` and checks proximity to `playerPos`.
#     - `ItemPickupHandler.triggerPickup(itemData, quantity, droppedItemEntity)`: Calls `InventoryManager.addItem` and signals world to remove entity.
#     - `ItemDropHandler.dropItem(itemData, quantity, playerPos)`: Calls `InventoryManager.removeItem` and creates a new dropped item entity in the world.
#     - `ItemPickupHandler.droppedItems`: Initialize as an empty table (managed by `World`).
#  - **Dependencies:** Phase 1 (InventoryManager), Phase 2 (InventoryUI for context menu/drag-drop initiation).
#
# **Phase 4: Item Usage and Equipment (Days 10-12)**
#  - **Priority:** High
#  - **Files to create:**
#     - `src/inventory/ItemUsageHandler.lua`
#  - **Files to modify:**
#     - `main.lua` (to require `ItemUsageHandler`)
#     - `src/inventory/InventoryUI.lua` (to add context menu for "Use" and "Equip")
#     - `src/player/PlayerStatsSystem.lua` (assuming this exists, for stat modifications)
#  - **Key functions to implement:**
#     - `ItemUsageHandler.useItem(itemData, slotIndex)`: Applies item effects (e.g., health boost) and calls `InventoryManager.removeItem`.
#     - `ItemUsageHandler.itemEffects`: Table mapping effect identifiers to functions.
#     - `InventoryManager.moveItem(fromSlot, toSlot)`: Swaps items between inventory slots and equipment slots.
#     - `InventoryManager.applyEquipmentStats(statsModifier)`: Calls `PlayerStatsSystem` to apply stat changes.
#     - `InventoryManager.removeEquipmentStats(statsModifier)`: Calls `PlayerStatsSystem` to remove stat changes.
#     - `InventoryUI.showContextMenu(itemData, slotIndex)`: Displays context menu with "Use", "Equip", "Drop" options.
#  - **Dependencies:** Phase 1 (InventoryManager), Phase 2 (InventoryUI), Phase 3 (ItemDropHandler for dropping from context menu).
#
# **Phase 5: Advanced Inventory Features (Sorting, Filtering, Tooltips) (Days 13-15)**
#  - **Priority:** Medium
#  - **Files to modify:**
#     - `src/inventory/InventoryManager.lua`
#     - `src/inventory/InventoryUI.lua`
#  - **Key functions to implement:**
#     - `InventoryManager.sortInventory()`: Implements sorting logic for `inventorySlots`.
#     - `InventoryManager.filterInventory(query)`: Implements filtering logic for `inventorySlots`.
#     - `InventoryUI.showTooltip(itemData)`: Displays item details on hover.
#     - `InventoryUI.hideTooltip()`: Hides the tooltip.
#     - `InventoryUI.handleInput(event)`: Add logic for hover detection and context menu triggers.
#  - **Dependencies:** Phase 1 (InventoryManager), Phase 2 (InventoryUI).
#
# **Phase 6: Persistence (Days 16-17)**
#  - **Priority:** High
#  - **Files to modify:**
#     - `src/inventory/InventoryManager.lua`
#     - `src/game/GameManager.lua` (or equivalent for save/load triggers)
#     - `src/save/SaveSystem.lua` (assuming this exists)
#  - **Key functions to implement:**
#     - `InventoryManager.saveInventory()`: Serializes `inventorySlots` and `equippedItems`.
#     - `InventoryManager.loadInventory(savedData)`: Deserializes and populates `inventorySlots` and `equippedItems`.
#  - **Dependencies:** Phase 1 (InventoryManager).
#
# ## Integration Instructions
#
# *   **Where to call new code:**
#     *   `main.lua`: `require` all inventory modules.
#     *   `src/input/InputHandler.lua`: Call `InventoryUI.toggleInventoryVisibility()` on 'I' key press.
#     *   `src/player/PlayerController.lua`: Call `ItemPickupHandler.checkPickup(player.position, World.droppedItems)` in the game loop.
#     *   `src/world/World.lua`: Manage `droppedItems` list and remove entities upon successful pickup.
#     *   `src/game/GameManager.lua`: Call `InventoryManager.saveInventory()` on game save and `InventoryManager.loadInventory(savedData)` on game load.
#     *   `src/player/PlayerStatsSystem.lua`: `InventoryManager` will call methods like `applyEquipmentStats` and `removeEquipmentStats`. `ItemUsageHandler` will call methods like `modifyHealth`.
#
# *   **Required imports:**
#     *   `require("src.inventory.InventoryManager")`
#     *   `require("src.inventory.ItemDatabase")`
#     *   `require("src.inventory.InventoryUI")`
#     *   `require("src.inventory.ItemPickupHandler")`
#     *   `require("src.inventory.ItemDropHandler")`
#     *   `require("src.inventory.ItemUsageHandler")`
#     *   `require("src.inventory.InventoryConstants")`
#
# *   **Initialization:**
#     *   In `main.lua` or a dedicated `GameManager`:
#         *   `ItemDatabase.loadItems("data/items.json")`
#         *   `inventoryManager = InventoryManager.new()`
#         *   `inventoryUI = InventoryUI.new(inventoryManager)`
#         *   `itemPickupHandler = ItemPickupHandler.new(inventoryManager)`
#         *   `itemDropHandler = ItemDropHandler.new(inventoryManager)`
#         *   `itemUsageHandler = ItemUsageHandler.new(inventoryManager)`
#
# *   **Game loop integration:**
#     *   `love.update(dt)`:
#         *   Call `ItemPickupHandler.checkPickup(player.position, World.droppedItems)` if inventory is not open.
#     *   `love.draw()`:
#         *   If `InventoryUI.isVisible`, call `InventoryUI.drawInventory(inventoryManager.inventorySlots)` and `InventoryUI.drawEquipmentSlots(inventoryManager.equippedItems)`.
#     *   `love.keypressed(key)`:
#         *   If `key == "i"`, call `InventoryUI.toggleInventoryVisibility()`.
#     *   `love.mousepressed(x, y, button)`:
#         *   If `InventoryUI.isVisible`, call `InventoryUI.handleInput({ type = "mousepressed", x = x, y = y, button = button })`.
#     *   `love.mousemoved(x, y)`:
#         *   If `InventoryUI.isVisible`, call `InventoryUI.handleInput({ type = "mousemoved", x = x, y = y })`.
#     *   `love.mousereleased(x, y, button)`:
#         *   If `InventoryUI.isVisible`, call `InventoryUI.handleInput({ type = "mousereleased", x = x, y = y, button = button })`.
#
# ## Testing Requirements
#
# **ItemDatabase:**
#  - **Unit tests:**
#     - `getItemDefinition(itemID)`: Test with valid and invalid item IDs.
#     - `getAllItemDefinitions()`: Test if it returns all items and if the structure is correct.
#  - **Integration tests:**
#     - Ensure `InventoryManager.addItem` correctly retrieves item data from `ItemDatabase`.
#  - **Manual testing steps:**
#     - Verify that `data/items.json` can be loaded without errors.
#     - Check that `ItemDatabase:getItemDefinition("some_item_id")` returns the expected item properties.
#
# **InventoryManager:**
#  - **Unit tests:**
#     - `addItem(itemData, quantity)`: Test adding new items, stacking existing items, exceeding max stack, adding to full inventory.
#     - `removeItem(slotIndex, quantity)`: Test removing full quantity, partial quantity, removing more than available, removing from empty slot.
#     - `moveItem(fromSlot, toSlot)`: Test swapping items, moving to empty slot, moving to occupied slot.
#     - `findEmptySlot()`: Test finding an empty slot when available and when inventory is full.
#  - **Integration tests:**
#     - Test the full flow of picking up an item: `ItemPickupHandler` calls `addItem`, then `removeItem` from world.
#     - Test equipping an item: `InventoryUI` calls `moveItem` to equipment slot, verify `equippedItems` and stat changes via `PlayerStatsSystem`.
#     - Test using a consumable: `ItemUsageHandler` calls `removeItem`.
#  - **Manual testing steps:**
#     - Add items to inventory, verify quantities and stacking.
#     - Remove items, verify quantities decrease correctly.
#     - Move items between slots.
#     - Equip and unequip items, verify `equippedItems` table and player stats.
#     - Use consumable items, verify effects and removal from inventory.
#
# **InventoryUI:**
#  - **Unit tests:**
#     - `toggleInventoryVisibility()`: Test if visibility state is correctly toggled.
#     - `drawInventory()`: Mock `inventorySlots` and verify that icons and quantities are drawn at correct positions (visual inspection).
#     - `drawEquipmentSlots()`: Mock `equippedItems` and verify drawing.
#     - `handleInput()`: Test mouse clicks on slots, drag-and-drop initiation, context menu opening.
#  - **Integration tests:**
#     - Open inventory with 'I' key, verify UI appears.
#     - Click on an item, verify context menu appears with correct options.
#     - Drag an item from inventory to an equipment slot, verify `moveItem` is called and item is equipped.
#     - Drag an item out of the inventory, verify `dropItem` is called.
#     - Hover over an item, verify tooltip appears with correct information.
#  - **Manual testing steps:**
#     - Press 'I' to open and close the inventory.
#     - Verify inventory grid and equipment slots are displayed correctly.
#     - Click on items to open context menus.
#     - Perform drag-and-drop operations for moving, equipping, and dropping.
#     - Hover over items to check tooltips.
#
# **ItemPickupHandler:**
#  - **Unit tests:**
#     - `checkPickup(playerPos, droppedItems)`: Test with player near, far, and on top of dropped items.
#  - **Integration tests:**
#     - Simulate a dropped item in the world.
#     - Move the player near the dropped item.
#     - Verify `InventoryManager.addItem` is called with the correct item and quantity.
#     - Verify the dropped item entity is removed from the world.
#  - **Manual testing steps:**
#     - Place a dropped item in the game world.
#     - Move the player character close to the dropped item.
#     - Verify the item is automatically added to the inventory.
#
# **ItemDropHandler:**
#  - **Unit tests:**
#     - `dropItem(itemData, quantity, playerPos)`: Verify `InventoryManager.removeItem` is called and a dropped item entity is created.
#  - **Integration tests:**
#     - Select an item in the inventory.
#     - Use the "Drop" context menu option or drag it outside the inventory.
#     - Verify the item is removed from the inventory.
#     - Verify a new dropped item entity appears in the game world at the player's position.
#  - **Manual testing steps:**
#     - Select an item in the inventory.
#     - Use the "Drop" option.
#     - Verify the item is removed from the inventory and appears as a dropped item in the game world.
#
# **ItemUsageHandler:**
#  - **Unit tests:**
#     - `useItem(itemData, slotIndex)`: Test with consumable items, verify correct effect is applied and item is removed.
#  - **Integration tests:**
#     - Select a consumable item in the inventory.
#     - Use the "Use" context menu option.
#     - Verify the item's effect is applied (e.g., player health increases).
#     - Verify the item is removed from the inventory.
#  - **Manual testing steps:**
#     - Select a health potion.
#     - Use the "Use" option.
#     - Verify player's health increases.
#     - Verify the health potion is removed from the inventory.
#
# **Persistence:**
#  - **Unit tests:**
#     - `saveInventory()`: Verify that `inventorySlots` and `equippedItems` are serialized correctly.
#     - `loadInventory(savedData)`: Verify that serialized data correctly populates `inventorySlots` and `equippedItems`.
#  - **Integration tests:**
#     - Add items, equip items, then save the game.
#     - Load the game, verify the inventory and equipped items are restored correctly.
#  - **Manual testing steps:**
#     - Populate inventory, equip items.
#     - Save the game.
#     - Close and reopen the game.
#     - Verify that the inventory and equipped items are exactly as they were before saving.
#
# ## File Structure
# ```
# [project_folder]/
# ├── main.lua
# ├── src/
# │   ├── inventory/
# │   │   ├── InventoryManager.lua
# │   │   ├── ItemDatabase.lua
# │   │   ├── InventoryUI.lua
# │   │   ├── ItemPickupHandler.lua
# │   │   ├── ItemDropHandler.lua
# │   │   ├── ItemUsageHandler.lua
# │   │   └── InventoryConstants.lua
# │   ├── input/
# │   │   └── InputHandler.lua
# │   ├── player/
# │   │   ├── PlayerController.lua
# │   │   └── PlayerStatsSystem.lua
# │   ├── world/
# │   │   └── World.lua
# │   └── game/
# │       └── GameManager.lua
# │   └── save/
# │       └── SaveSystem.lua
# └── data/
#     └── items.json
# ```
#
# ---
# ap_review
# document_type='architecture_plan' review_output=ArchitectureReviewOutput(review_status='Approved', review_notes='', completeness_score=5, feasibility_score=5, simplicity_score=5) review_count=1 max_reviews_allowed=3
#
# ---
# fip_review
# document_type='feature_implementation_plan' review_output=FIPReviewOutput(review_status='Approved', review_notes='', completeness_score=5, implementation_score=5, alignment_score=5) review_count=1 max_reviews_allowed=3

# %%
print(
    parse_review_response(
        content="""
        ```json
{
  "review_status": "Approved",
  "completeness_score": 5,
  "implementation_score": 5,
  "alignment_score": 5,
  "review_notes": ""
}
```
        """, 
        review_type="fip")
)
# Out:
# review_status='Approved' review_notes='' completeness_score=5 implementation_score=5 alignment_score=5
